# %%
from PIL import Image

def make_square(im, min_size=256, fill_color=(0, 0, 0, 0)):
    x, y = im.size
    size = max(min_size, x, y)
    new_im = Image.new('RGBA', (size, size), fill_color)
    new_im.paste(im, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

# %% [markdown]
# # inbreast

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/inbreast/croponly/train/imagefortrain90'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
filename_list    
for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original_img = Image.open('E:/Alldata/inbreast/correct/renameimg/'+file_name)
    original_mask = Image.open('E:/Alldata/inbreast/correct/renamelabel/'+file_name)
    #original_img = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/image_0.png')
    #original_mask = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/mask_0.png')
    original_img.save('E:/Alldata/inbreast/correct/spilt/train/image/'+file_name)
    original_mask.save('E:/Alldata/inbreast/correct/spilt/train/label/'+file_name)
    original_img_temp = make_square(original_img)
    original_mask_temp = make_square(original_mask)
    #original_mask_temp.resize((512, 512)).convert('L').save("C:/Users/414/Desktop/inbreast/view/mask_train/"+img_name_temp[0]+".png")
    
    numimg = 32        #8、58
    anglecal = 360 / numimg 
    for angle in range(0,360,int(anglecal+1)):
        new_image = original_img_temp.rotate(angle+1)
        new_image = new_image.resize((512, 512)).convert('L')
        new_image.save("E:/Alldata/inbreast/correct/image_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
        new_mask  = original_mask_temp.rotate(angle+1)
        new_mask = new_mask.resize((512, 512)).convert('L')
        new_mask.save("E:/Alldata/inbreast/correct/mask_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
    #new_img_180  = original_img_temp.transpose(Image.ROTATE_180) 
    #new_img_180 = new_img_180.resize((512, 512)).convert('L')
    #new_img_180.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_mask_180 = original_mask_temp.transpose(Image.ROTATE_180) 
    #new_mask_180 = new_mask_180.resize((512, 512)).convert('L')
    #new_mask_180.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_img_270=original_img_temp.transpose(Image.ROTATE_270) 
    #new_img_270 = new_img_270.resize((512, 512)).convert('L')
    #new_img_270.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    #
    #new_mask_270 = original_mask_temp.transpose(Image.ROTATE_270) 
    #new_mask_270 = new_mask_270.resize((512, 512)).convert('L')
    #new_mask_270.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    
    #print('success'+img_name_temp[0])
# Out:
# path： E:/Alldata/inbreast/croponly/train/imagefortrain90
# directory： []
# file： ['20586908.png', '20586934.png', '20586960.png', '20586986.png', '20587810.png', '20587902.png', '20587994.png', '20588046.png', '20588190.png', '20588216.png', '20588308.png', '20588334.png', '20588536.png', '20588562.png', '20588680.png', '22427705.png', '22427751.png', '22579730.png', '22580038.png', '22580098.png', '22580192.png', '22580244.png', '22580341.png', '22580367.png', '22580393.png', '22580419.png', '22580654.png', '22580680.png', '22580706.png', '22580732.png', '22613650.png', '22613702.png', '22613770.png', '22613822.png', '22614074.png', '22614236.png', '22614266.png', '22614379.png', '22614431.png', '22614522.png', '22614568.png', '22670147.png', '22670278.png', '22670324.png', '22670465.png', '22670511.png', '22670673.png', '22670809.png', '22670855.png', '22678646.png', '22678694.png', '22678787.png', '22678833.png', '24055464.png', '24055483.png', '24055502.png', '24065251.png', '24065289.png', '24065530.png', '24065707.png', '24065761.png', '27829134.png', '27829188.png', '30011553.png', '30011727.png', '50994273.png', '50994354.png', '50994408.png', '50995762.png', '50995789.png', '50996352.png', '50996406.png', '50997461.png', '50998981.png', '50999008.png', '50999432.png', '50999459.png', '51048765.png', '51049053.png', '51049107.png', '53580804.png', '53580858.png', '53581406.png', '53581460.png', '53582683.png', '53586869.png', '53586896.png', '53586960.png', '53587014.png', '53587663.png']

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/inbreast/correct/image_train/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
i=0    
for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original_img = Image.open('E:/Alldata/inbreast/correct/image_train/'+file_name)
    original_mask = Image.open('E:/Alldata/inbreast/correct/mask_train/'+file_name)
    #print(file_name)
    new_img=original_img.transpose(Image.FLIP_LEFT_RIGHT).convert('L') 
    new_mask= original_mask.transpose(Image.FLIP_LEFT_RIGHT).convert('L')
    original_img.save('E:/Alldata/inbreast/correct/traincomb/image_'+ str(i) +'.png')
    original_mask.save('E:/Alldata/inbreast/correct/traincomb/mask_'+ str(i)+'.png')
    i=i+1
    new_img.save('E:/Alldata/inbreast/correct/traincomb/image_'+ str(i) +'.png')
    new_mask.save('E:/Alldata/inbreast/correct/traincomb/mask_'+ str(i) +'.png')
    i=i+1
    #print('success'+img_name_temp[0])
# Out:
# path： E:/Alldata/inbreast/correct/image_train/
# directory： []
# file： ['20586908_rotate_1.png', '20586908_rotate_109.png', '20586908_rotate_121.png', '20586908_rotate_13.png', '20586908_rotate_133.png', '20586908_rotate_145.png', '20586908_rotate_157.png', '20586908_rotate_169.png', '20586908_rotate_181.png', '20586908_rotate_193.png', '20586908_rotate_205.png', '20586908_rotate_217.png', '20586908_rotate_229.png', '20586908_rotate_241.png', '20586908_rotate_25.png', '20586908_rotate_253.png', '20586908_rotate_265.png', '20586908_rotate_277.png', '20586908_rotate_289.png', '20586908_rotate_301.png', '20586908_rotate_313.png', '20586908_rotate_325.png', '20586908_rotate_337.png', '20586908_rotate_349.png', '20586908_rotate_37.png', '20586908_rotate_49.png', '20586908_rotate_61.png', '20586908_rotate_73.png', '20586908_rotate_85.png', '20586908_rotate_97.png', '20586934_rotate_1.png', '20586934_rotate_109.png', '20586934_rotate_121.png', '20586934_rotate_13.png', '20586934_rotate_133.png', '20586934_rotate_145.png', '20586934_rotate_157.png', '20586934_rotate_169.png', '20586934_rotate_181.png', '20586934_rotate_193.png', '20586934_rotate_205.png', '20586934_rotate_217.png', '20586934_rotate_229.png', '20586934_rotate_241.png', '20586934_rotate_25.png', '20586934_rotate_253.png', '20586934_rotate_265.png', '20586934_rotate_277.png', '20586934_rotate_289.png', '20586934_rotate_301.png', '20586934_rotate_313.png', '20586934_rotate_325.png', '20586934_rotate_337.png', '20586934_rotate_349.png', '20586934_rotate_37.png', '20586934_rotate_49.png', '20586934_rotate_61.png', '20586934_rotate_73.png', '20586934_rotate_85.png', '20586934_rotate_97.png', '20586960_rotate_1.png', '20586960_rotate_109.png', '20586960_rotate_121.png', '20586960_rotate_13.png', '20586960_rotate_133.png', '20586960_rotate_145.png', '20586960_rotate_157.png', '20586960_rotate_169.png', '20586960_rotate_181.png', '20586960_rotate_193.png', '20586960_rotate_205.png', '20586960_rotate_217.png', '20586960_rotate_229.png', '20586960_rotate_241.png', '20586960_rotate_25.png', '20586960_rotate_253.png', '20586960_rotate_265.png', '20586960_rotate_277.png', '20586960_rotate_289.png', '20586960_rotate_301.png', '20586960_rotate_313.png', '20586960_rotate_325.png', '20586960_rotate_337.png', '20586960_rotate_349.png', '20586960_rotate_37.png', '20586960_rotate_49.png', '20586960_rotate_61.png', '20586960_rotate_73.png', '20586960_rotate_85.png', '20586960_rotate_97.png', '20586986_rotate_1.png', '20586986_rotate_109.png', '20586986_rotate_121.png', '20586986_rotate_13.png', '20586986_rotate_133.png', '20586986_rotate_145.png', '20586986_rotate_157.png', '20586986_rotate_169.png', '20586986_rotate_181.png', '20586986_rotate_193.png', '20586986_rotate_205.png', '20586986_rotate_217.png', '20586986_rotate_229.png', '20586986_rotate_241.png', '20586986_rotate_25.png', '20586986_rotate_253.png', '20586986_rotate_265.png', '20586986_rotate_277.png', '20586986_rotate_289.png', '20586986_rotate_301.png', '20586986_rotate_313.png', '20586986_rotate_325.png', '20586986_rotate_337.png', '20586986_rotate_349.png', '20586986_rotate_37.png', '20586986_rotate_49.png', '20586986_rotate_61.png', '20586986_rotate_73.png', '20586986_rotate_85.png', '20586986_rotate_97.png', '20587810_rotate_1.png', '20587810_rotate_109.png', '20587810_rotate_121.png', '20587810_rotate_13.png', '20587810_rotate_133.png', '20587810_rotate_145.png', '20587810_rotate_157.png', '20587810_rotate_169.png', '20587810_rotate_181.png', '20587810_rotate_193.png', '20587810_rotate_205.png', '20587810_rotate_217.png', '20587810_rotate_229.png', '20587810_rotate_241.png', '20587810_rotate_25.png', '20587810_rotate_253.png', '20587810_rotate_265.png', '20587810_rotate_277.png', '20587810_rotate_289.png', '20587810_rotate_301.png', '20587810_rotate_313.png', '20587810_rotate_325.png', '20587810_rotate_337.png', '20587810_rotate_349.png', '20587810_rotate_37.png', '20587810_rotate_49.png', '20587810_rotate_61.png', '20587810_rotate_73.png', '20587810_rotate_85.png', '20587810_rotate_97 ...

# %% [markdown]
# # DDSM

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/tumor_ddsm/correct/spilt/train/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
filename_list    
for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original_img = Image.open('E:/Alldata/tumor_ddsm/correct/image/'+file_name)
    original_mask = Image.open('E:/Alldata/tumor_ddsm/correct/label/'+file_name)
    #original_img = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/image_0.png')
    #original_mask = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/mask_0.png')
    #original_img.save('E:/Alldata/inbreast/correct/spilt/train/image/'+file_name)
    #original_mask.save('E:/Alldata/inbreast/correct/spilt/train/label/'+file_name)
    original_img_temp = make_square(original_img)
    original_mask_temp = make_square(original_mask)
    #original_mask_temp.resize((512, 512)).convert('L').save("C:/Users/414/Desktop/inbreast/view/mask_train/"+img_name_temp[0]+".png")
    
    numimg = 5        #8、58
    anglecal = 360 / numimg 
    for angle in range(0,360,int(anglecal+1)):
        new_image = original_img_temp.rotate(angle+1)
        new_image = new_image.resize((512, 512)).convert('L')
        new_image.save("E:/Alldata/tumor_ddsm/correct/image_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
        new_mask  = original_mask_temp.rotate(angle+1)
        new_mask = new_mask.resize((512, 512)).convert('L')
        new_mask.save("E:/Alldata/tumor_ddsm/correct/mask_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
    #new_img_180  = original_img_temp.transpose(Image.ROTATE_180) 
    #new_img_180 = new_img_180.resize((512, 512)).convert('L')
    #new_img_180.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_mask_180 = original_mask_temp.transpose(Image.ROTATE_180) 
    #new_mask_180 = new_mask_180.resize((512, 512)).convert('L')
    #new_mask_180.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_img_270=original_img_temp.transpose(Image.ROTATE_270) 
    #new_img_270 = new_img_270.resize((512, 512)).convert('L')
    #new_img_270.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    #
    #new_mask_270 = original_mask_temp.transpose(Image.ROTATE_270) 
    #new_mask_270 = new_mask_270.resize((512, 512)).convert('L')
    #new_mask_270.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    
    #print('success'+img_name_temp[0])
# Out:
# path： E:/Alldata/tumor_ddsm/correct/spilt/train/
# directory： ['image', 'label']
# file： []
# path： E:/Alldata/tumor_ddsm/correct/spilt/train/image
# directory： []
# file： ['Mass-Test_P_00017_LEFT_CC.png', 'Mass-Test_P_00017_LEFT_MLO.png', 'Mass-Test_P_00037_RIGHT_CC.png', 'Mass-Test_P_00037_RIGHT_MLO.png', 'Mass-Test_P_00056_LEFT_MLO.png', 'Mass-Test_P_00066_LEFT_CC.png', 'Mass-Test_P_00066_LEFT_MLO.png', 'Mass-Test_P_00099_LEFT_MLO.png', 'Mass-Test_P_00114_LEFT_MLO.png', 'Mass-Test_P_00116_RIGHT_CC.png', 'Mass-Test_P_00116_RIGHT_MLO.png', 'Mass-Test_P_00118_RIGHT_CC.png', 'Mass-Test_P_00118_RIGHT_MLO.png', 'Mass-Test_P_00124_RIGHT_CC.png', 'Mass-Test_P_00126_RIGHT_CC.png', 'Mass-Test_P_00126_RIGHT_MLO.png', 'Mass-Test_P_00131_LEFT_CC.png', 'Mass-Test_P_00131_LEFT_MLO.png', 'Mass-Test_P_00147_RIGHT_CC.png', 'Mass-Test_P_00147_RIGHT_MLO.png', 'Mass-Test_P_00156_RIGHT_MLO.png', 'Mass-Test_P_00158_RIGHT_MLO.png', 'Mass-Test_P_00159_RIGHT_MLO.png', 'Mass-Test_P_00171_RIGHT_CC.png', 'Mass-Test_P_00171_RIGHT_MLO.png', 'Mass-Test_P_00173_LEFT_CC.png', 'Mass-Test_P_00173_LEFT_MLO.png', 'Mass-Test_P_00173_RIGHT_CC.png', 'Mass-Test_P_00173_RIGHT_MLO.png', 'Mass-Test_P_00177_LEFT_CC.png', 'Mass-Test_P_00177_LEFT_MLO.png', 'Mass-Test_P_00192_RIGHT_CC.png', 'Mass-Test_P_00194_RIGHT_CC.png', 'Mass-Test_P_00194_RIGHT_MLO.png', 'Mass-Test_P_00198_LEFT_CC.png', 'Mass-Test_P_00198_LEFT_MLO.png', 'Mass-Test_P_00200_LEFT_MLO.png', 'Mass-Test_P_00200_RIGHT_CC.png', 'Mass-Test_P_00200_RIGHT_MLO.png', 'Mass-Test_P_00202_RIGHT_CC.png', 'Mass-Test_P_00203_LEFT_CC.png', 'Mass-Test_P_00203_LEFT_MLO.png', 'Mass-Test_P_00209_LEFT_MLO.png', 'Mass-Test_P_00212_RIGHT_CC.png', 'Mass-Test_P_00212_RIGHT_MLO.png', 'Mass-Test_P_00230_
...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7488/1556202356.py in <module>
#      31
#      32         new_mask  = original_mask_temp.rotate(angle+1)
# ---> 33         new_mask = new_mask.resize((512, 512)).convert('L')
#      34         new_mask.save("E:/Alldata/tumor_ddsm/correct/mask_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
#      35
#
# ~\anaconda3\envs\unet\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    1983
#    1984         if self.mode in ["LA", "RGBA"] and resample != NEAREST:
# -> 1985             im = self.convert({"LA": "La", "RGBA": "RGBa"}[self.mode])
#    1986             im = im.resize(size, resample, box)
#    1987             return im.convert(self.mode)
#
# ~\anaconda3\envs\unet\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#    1044
#    1045         try:
# -> 1046             im = self.im.convert(mode, dither)
#    1047         except ValueError:
#    1048             try:
#
# KeyboardInterrupt:

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/tumor_ddsm/correct/image_train/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
i=0    
for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original_img = Image.open('E:/Alldata/tumor_ddsm/correct/image_train/'+file_name)
    original_mask = Image.open('E:/Alldata/tumor_ddsm/correct/mask_train/'+file_name)
    #print(file_name)
    new_img=original_img.transpose(Image.FLIP_LEFT_RIGHT).convert('L') 
    new_mask= original_mask.transpose(Image.FLIP_LEFT_RIGHT).convert('L')
    original_img.save('E:/Alldata/tumor_ddsm/correct/traincomb/image_'+ str(i) +'.png')
    original_mask.save('E:/Alldata/tumor_ddsm/correct/traincomb/mask_'+ str(i)+'.png')
    i=i+1
    new_img.save('E:/Alldata/tumor_ddsm/correct/traincomb/image_'+ str(i) +'.png')
    new_mask.save('E:/Alldata/tumor_ddsm/correct/traincomb/mask_'+ str(i) +'.png')
    i=i+1
    #print('success'+img_name_temp[0])

# %% [markdown]
# # hospital

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/hospital/trainbeforecrop/93label_uncrop'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
filename_list    
for file_name in filename_list:
    img_name_temp = file_name.split("mask")
    original_img = Image.open('E:/Alldata/hospital/trainbeforecrop/93image_uncrop/'+img_name_temp[0]+'.jpg')
    original_mask = Image.open('E:/Alldata/hospital/trainbeforecrop/93label_uncrop/'+file_name)
    #original_img = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/image_0.png')
    #original_mask = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/mask_0.png')
    #original_img.save('E:/Alldata/inbreast/correct/spilt/train/image/'+file_name)
    #original_mask.save('E:/Alldata/inbreast/correct/spilt/train/label/'+file_name)
    original_img_temp = make_square(original_img)
    original_mask_temp = make_square(original_mask)
    #original_mask_temp.resize((512, 512)).convert('L').save("C:/Users/414/Desktop/inbreast/view/mask_train/"+img_name_temp[0]+".png")
    
    numimg = 32        #8、58
    anglecal = 360 / numimg 
    for angle in range(0,360,int(anglecal+1)):
        new_image = original_img_temp.rotate(angle+1)
        new_image = new_image.resize((512, 512)).convert('L')
        new_image.save("E:/Alldata/hospital/trainez/image_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
        new_mask  = original_mask_temp.rotate(angle+1)
        new_mask = new_mask.resize((512, 512)).convert('L')
        new_mask.save("E:/Alldata/hospital/trainez/mask_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/hospital/trainez/mask_train/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
i=0    
for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original_img = Image.open('E:/Alldata/hospital/trainez/image_train/'+file_name)
    original_mask = Image.open('E:/Alldata/hospital/trainez/mask_train/'+file_name)
    #print(file_name)
    new_img=original_img.transpose(Image.FLIP_LEFT_RIGHT).convert('L') 
    new_mask= original_mask.transpose(Image.FLIP_LEFT_RIGHT).convert('L')
    original_img.save('E:/Alldata/hospital/trainez/dataset_chenhsin_combine/image_'+ str(i) +'.png')
    original_mask.save('E:/Alldata/hospital/trainez/dataset_chenhsin_combine/mask_'+ str(i)+'.png')
    i=i+1
    new_img.save('E:/Alldata/hospital/trainez/dataset_chenhsin_combine/image_'+ str(i) +'.png')
    new_mask.save('E:/Alldata/hospital/trainez/dataset_chenhsin_combine/mask_'+ str(i) +'.png')
    i=i+1
    #print('success'+img_name_temp[0])
# Out:
# path： E:/Alldata/hospital/trainez/mask_train/
# directory： []
# file： ['1128417_3_rotate_1.png', '1128417_3_rotate_109.png', '1128417_3_rotate_121.png', '1128417_3_rotate_13.png', '1128417_3_rotate_133.png', '1128417_3_rotate_145.png', '1128417_3_rotate_157.png', '1128417_3_rotate_169.png', '1128417_3_rotate_181.png', '1128417_3_rotate_193.png', '1128417_3_rotate_205.png', '1128417_3_rotate_217.png', '1128417_3_rotate_229.png', '1128417_3_rotate_241.png', '1128417_3_rotate_25.png', '1128417_3_rotate_253.png', '1128417_3_rotate_265.png', '1128417_3_rotate_277.png', '1128417_3_rotate_289.png', '1128417_3_rotate_301.png', '1128417_3_rotate_313.png', '1128417_3_rotate_325.png', '1128417_3_rotate_337.png', '1128417_3_rotate_349.png', '1128417_3_rotate_37.png', '1128417_3_rotate_49.png', '1128417_3_rotate_61.png', '1128417_3_rotate_73.png', '1128417_3_rotate_85.png', '1128417_3_rotate_97.png', '1600750_2_rotate_1.png', '1600750_2_rotate_109.png', '1600750_2_rotate_121.png', '1600750_2_rotate_13.png', '1600750_2_rotate_133.png', '1600750_2_rotate_145.png', '1600750_2_rotate_157.png', '1600750_2_rotate_169.png', '1600750_2_rotate_181.png', '1600750_2_rotate_193.png', '1600750_2_rotate_205.png', '1600750_2_rotate_217.png', '1600750_2_rotate_229.png', '1600750_2_rotate_241.png', '1600750_2_rotate_25.png', '1600750_2_rotate_253.png', '1600750_2_rotate_265.png', '1600750_2_rotate_277.png', '1600750_2_rotate_289.png', '1600750_2_rotate_301.png', '1600750_2_rotate_313.png', '1600750_2_rotate_325.png', '1600750_2_rotate_337.png', '1600750_2_rotate_349.png', '1600750_2_rotate_37.png', '1600750_2_rotate_49.png', '1600750_2_rotate_61.png', '1600750_2_rotate_73.png', '1600750_2_rotate_85.png', '1600750_2_rotate_97.png', '1600750_4_rotate_1.png', '1600750_4_rotate_109.png', '1600750_4_rotate_121.png', '1600750_4_rotate_13.png', '1600750_4_rotate_133.png', '1600750_4_rotate_145.png', '1600750_4_rotate_157.png', '1600750_4_rotate_169.png', '1600750_4_rotate_181.png', '1600750_4_rotate_193.png', '1600750_4_rotate_205.png', '1600750_4_rotate_217.png', '1600750_4_rotate_229.png', '1600750_4_rotate_241.png', '1600750_4_rotate_25.png', '1600750_4_rotate_253.png', '1600750_4_rotate_265.png', '1600750_4_rotate_277.png', '1600750_4_rotate_289.png', '1600750_4_rotate_301.png', '1600750_4_rotate_313.png', '1600750_4_rotate_325.png', '1600750_4_rotate_337.png', '1600750_4_rotate_349.png', '1600750_4_rotate_37.png', '1600750_4_rotate_49.png', '1600750_4_rotate_61.png', '1600750_4_rotate_73.png', '1600750_4_rotate_85.png', '1600750_4_rotate_97.png', '1816682_1_rotate_1.png', '1816682_1_rotate_109.png', '1816682_1_rotate_121.png', '1816682_1_rotate_13.png', '1816682_1_rotate_133.png', '1816682_1_rotate_145.png', '1816682_1_rotate_157.png', '1816682_1_rotate_169.png', '1816682_1_rotate_181.png', '1816682_1_rotate_193.png', '1816682_1_rotate_205.png', '1816682_1_rotate_217.png', '1816682_1_rotate_229.png', '1816682_1_rotate_241.png', '1816682_1_rotate_25.png', '1816682_1_rotate_253.png', '1816682_1_rotate_265.png', '1816682_1_rotate_277.png', '1816682_1_rotate_289.png', '1816682_1_rotate_301.png', '1816682_1_rotate_313.png', '1816682_1_rotate_325.png', '1816682_1_rotate_337.png', '1816682_1_rotate_349.png', '1816682_1_rotate_37.png', '1816682_1_rotate_49.png', '1816682_1_rotate_61.png', '1816682_1_rotate_73.png', '1816682_1_rotate_85.png', '1816682_1_rotate_97.png', '1816682_2_rotate_1.png', '1816682_2_rotate_109.png', '1816682_2_rotate_121.png', '1816682_2_rotate_13.png', '1816682_2_rotate_133.png', '1816682_2_rotate_145.png', '1816682_2_rotate_157.png', '1816682_2_rotate_169.png', '1816682_2_rotate_181.png', '1816682_2_rotate_193.png', '1816682_2_rotate_205.png', '1816682_2_rotate_217.png', '1816682_2_rotate_229.png', '1816682_2_rotate_241.png', '1816682_2_rotate_25.png', '1816682_2_rotate_253.png', '1816682_2_rotate_265.png', '1816682_2_rotate_277.png', '1816682_2_rotate_289.png', '1816682_2_rotate_301.png', '1816682_2_rotate_313.png', '1816682_2_rotate_325.png', '1816682_2_rotate_337.png', '1816682_2_rotate_349.png', '1816 ...

# %% [markdown]
# # hospital+inbreast

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/hospital/trainbeforecrop/93label_uncrop'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
filename_list    
for file_name in filename_list:
    img_name_temp = file_name.split("mask")
    original_img = Image.open('E:/Alldata/hospital/trainbeforecrop/93image_uncrop/'+img_name_temp[0]+'.jpg')
    original_mask = Image.open('E:/Alldata/hospital/trainbeforecrop/93label_uncrop/'+file_name)
    #original_img = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/image_0.png')
    #original_mask = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/mask_0.png')
    #original_img.save('E:/Alldata/inbreast/correct/spilt/train/image/'+file_name)
    #original_mask.save('E:/Alldata/inbreast/correct/spilt/train/label/'+file_name)
    original_img_temp = make_square(original_img)
    original_mask_temp = make_square(original_mask)
    #original_mask_temp.resize((512, 512)).convert('L').save("C:/Users/414/Desktop/inbreast/view/mask_train/"+img_name_temp[0]+".png")
    
    numimg = 5        #8、58
    anglecal = 360 / numimg 
    for angle in range(0,360,int(anglecal+1)):
        new_image = original_img_temp.rotate(angle+1)
        new_image = new_image.resize((512, 512)).convert('L')
        new_image.save("E:/Alldata/temp_image/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
        new_mask  = original_mask_temp.rotate(angle+1)
        new_mask = new_mask.resize((512, 512)).convert('L')
        new_mask.save("E:/Alldata/temp_mask/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
    #new_img_180  = original_img_temp.transpose(Image.ROTATE_180) 
    #new_img_180 = new_img_180.resize((512, 512)).convert('L')
    #new_img_180.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_mask_180 = original_mask_temp.transpose(Image.ROTATE_180) 
    #new_mask_180 = new_mask_180.resize((512, 512)).convert('L')
    #new_mask_180.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_img_270=original_img_temp.transpose(Image.ROTATE_270) 
    #new_img_270 = new_img_270.resize((512, 512)).convert('L')
    #new_img_270.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    #
    #new_mask_270 = original_mask_temp.transpose(Image.ROTATE_270) 
    #new_mask_270 = new_mask_270.resize((512, 512)).convert('L')
    #new_mask_270.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    
    #print('success'+img_name_temp[0])
# Out:
# path： E:/Alldata/hospital/trainbeforecrop/93label_uncrop
# directory： []
# file： ['1128417_3mask.jpg', '1600750_2mask.jpg', '1600750_4mask.jpg', '1816682_1mask.jpg', '1816682_2mask.jpg', '1955799_4mask.jpg', '2284660_3mask.jpg', '3028936_53mask.jpg', '3210438_1mask.jpg', '3210438_3mask.jpg', '3509188_1mask.jpg', '3509188_3mask.jpg', '3538141_1mask.jpg', '3538141_3mask.jpg', '3806392_4mask.jpg', '4020462_3mask.jpg', '5263734_3mask.jpg', '5650759_5mask.jpg', '5650759_7mask.jpg', '6219489_1mask.jpg', '6219489_3mask.jpg', '6743985_2mask.jpg', '6796885_1mask.jpg', '6796885_3mask.jpg', '7178088_1mask.jpg', '7318050_3mask.jpg', '7318050_5mask.jpg', '7886661_2mask.jpg', '7886661_4mask.jpg', '8450520_1mask.jpg', '8450520_3mask.jpg', '8824650_1mask.jpg', '8966446_1mask.jpg', '9122879_1mask.jpg', '9395193_2mask.jpg', '9395193_4mask.jpg', 'A128803_5mask.jpg', 'A128803_6mask.jpg', 'A699888_1mask.jpg', 'A699888_2mask.jpg', 'A699888_3mask.jpg', 'A699888_4mask.jpg', 'A726584_2mask.jpg', 'A726584_4mask.jpg', 'A828821_1mask.jpg', 'A828821_3mask.jpg', 'A979250_2mask.jpg', 'A979250_4mask.jpg', 'B120389_27mask.jpg', 'B241830_11mask.jpg', 'B241830_13mask.jpg', 'B304175_3mask.jpg', 'B597287_23mask.jpg', 'B597287_25mask.jpg', 'B980139_1mask.jpg', 'B980139_2mask.jpg', 'C046421_4mask.jpg', 'C064291_1mask.jpg', 'C064291_2mask.jpg', 'C074420_1mask.jpg', 'C074420_3mask.jpg', 'C075977_11mask.jpg', 'C077515_1mask.jpg', 'C077515_3mask.jpg', 'C128766_4mask.jpg', 'C153694_4mask.jpg', 'C193888_1mask.jpg', 'C193888_3mask.jpg', 'C213490_2mask.jpg', 'C213490_4mask.jpg', 'C247819_2mask.jpg', 'C251628_2mask.jpg', 'C251628_4mask.jpg', 'C261441_2mask.jpg', 'C266629_3mask.jpg', 'C266629_5mask.jpg', 'C278460_1mask.jpg', 'C278460_3mask.jpg', 'C278991_70mask.jpg', 'C288207_22mask.jpg', 'C288207_24mask.jpg', 'C290579_2mask.jpg', 'C290579_4mask.jpg', 'C361621_1mask.jpg', 'C393159_1mask.jpg', 'C403051_21mask.jpg', 'C403051_23mask.jpg', 'C410335_2mask.jpg', 'C410335_4mask.jpg', 'C437470_2mask.jpg', 'C437470_4mask.jpg', 'C456189_1mask.jpg', 'C456189_3mask.jpg']

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/tumor_ddsm/correct/spilt/train/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
filename_list    
for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original_img = Image.open('E:/Alldata/tumor_ddsm/correct/image/'+file_name)
    original_mask = Image.open('E:/Alldata/tumor_ddsm/correct/label/'+file_name)
    #original_img = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/image_0.png')
    #original_mask = Image.open('C:/Users/414/Desktop/unet-master/data/membrane_hospital_aughand/train/aug_new/mask_0.png')
    #original_img.save('E:/Alldata/inbreast/correct/spilt/train/image/'+file_name)
    #original_mask.save('E:/Alldata/inbreast/correct/spilt/train/label/'+file_name)
    original_img_temp = make_square(original_img)
    original_mask_temp = make_square(original_mask)
    #original_mask_temp.resize((512, 512)).convert('L').save("C:/Users/414/Desktop/inbreast/view/mask_train/"+img_name_temp[0]+".png")
    
    numimg = 5        #8、58
    anglecal = 360 / numimg 
    for angle in range(0,360,int(anglecal+1)):
        new_image = original_img_temp.rotate(angle+1)
        new_image = new_image.resize((512, 512)).convert('L')
        new_image.save("E:/Alldata/hospital_ddsm/image_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
        new_mask  = original_mask_temp.rotate(angle+1)
        new_mask = new_mask.resize((512, 512)).convert('L')
        new_mask.save("E:/Alldata/hospital_ddsm/mask_train/"+img_name_temp[0]+"_rotate_"+str(angle+1)+".png")
    
    #new_img_180  = original_img_temp.transpose(Image.ROTATE_180) 
    #new_img_180 = new_img_180.resize((512, 512)).convert('L')
    #new_img_180.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_mask_180 = original_mask_temp.transpose(Image.ROTATE_180) 
    #new_mask_180 = new_mask_180.resize((512, 512)).convert('L')
    #new_mask_180.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_180.png")
    #
    #new_img_270=original_img_temp.transpose(Image.ROTATE_270) 
    #new_img_270 = new_img_270.resize((512, 512)).convert('L')
    #new_img_270.save("./data/temp/imgbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    #
    #new_mask_270 = original_mask_temp.transpose(Image.ROTATE_270) 
    #new_mask_270 = new_mask_270.resize((512, 512)).convert('L')
    #new_mask_270.save("./data/temp/maskbeforeflip/"+img_name_temp[0]+"_rotate_270.png")
    
    #print('success'+img_name_temp[0])

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = 'E:/Alldata/hospital_ddsm/image_train/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
i=0    
for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original_img = Image.open('E:/Alldata/hospital_ddsm/image_train/'+file_name)
    original_mask = Image.open('E:/Alldata/hospital_ddsm/mask_train/'+file_name)
    #print(file_name)
    new_img=original_img.transpose(Image.FLIP_LEFT_RIGHT).convert('L') 
    new_mask= original_mask.transpose(Image.FLIP_LEFT_RIGHT).convert('L')
    original_img.save('E:/Alldata/hospital_ddsm/traincomb/image_'+ str(i) +'.png')
    original_mask.save('E:/Alldata/hospital_ddsm/traincomb/mask_'+ str(i)+'.png')
    i=i+1
    new_img.save('E:/Alldata/hospital_ddsm/traincomb/image_'+ str(i) +'.png')
    new_mask.save('E:/Alldata/hospital_ddsm/traincomb/mask_'+ str(i) +'.png')
    i=i+1
    #print('success'+img_name_temp[0])
