# %%
from model import *
from data import *
from nets.MaxPoolingWithIndices2D import MaxPoolingWithIndices2D
from nets.MaxUnpoolingWithIndices2D import MaxUnpoolingWithIndices2D

# %%
#Step 5: Define functions to evaluate the output
import sklearn.metrics as sm
from sklearn.metrics import plot_precision_recall_curve,confusion_matrix,precision_score,recall_score,f1_score,average_precision_score,PrecisionRecallDisplay
def get_confusion_matrix_elements(groundtruth_list, predicted_list):
    from tensorflow.python.keras.metrics import Metric    
    tn, fp, fn, tp = sm.confusion_matrix(groundtruth_list, predicted_list,labels=[0,1]).ravel()
    tn, fp, fn, tp = np.float64(tn), np.float64(fp), np.float64(fn), np.float64(tp)
    #print(sm.confusion_matrix(groundtruth_list, predicted_list,labels=[0,1]))
    return tn, fp, fn, tp
def plot_Micro_averaged_precision_recall_curve(groundtruth,predicted,threshold):    
    from tensorflow.python.keras.metrics import Metric
    u,v=np.shape(groundtruth)
    groundtruth_list=np.reshape(groundtruth,(u*v,))
    predicted_list=np.reshape(predicted,(u*v,))
    precision = dict()
    recall = dict()
    average_precision = dict()
    precision["micro"], recall["micro"], _ = precision_recall_curve(predicted_list.ravel(), groundtruth_list.ravel())
    average_precision["micro"] = average_precision_score(predicted_list, groundtruth_list, average="micro")
    display = PrecisionRecallDisplay(
        recall=recall["micro"],
        precision=precision["micro"],
        average_precision=average_precision["micro"],)
    display.plot()
    _ = display.ax_.set_title("Micro-averaged over all classes")
    
    return precision,recall


def plot_precision_recall_curve(groundtruth,predicted,threshold):    
    from tensorflow.python.keras.metrics import Metric
    u,v=np.shape(groundtruth)
    groundtruth_list=np.reshape(groundtruth,(u*v,))
    predicted_list=np.reshape(predicted,(u*v,))
    #threshold = 0.1
    #y_pred_mod = (predicted_list > threshold).astype(int)
    #print(y_pred_mod)
    display = PrecisionRecallDisplay.from_predictions(predicted_list, groundtruth_list, name="LinearSVC")
    _ = display.ax_.set_title("2-class Precision-Recall curve")
    precisions, recalls, thresholds = precision_recall_curve(groundtruth_list,predicted_list)
    #print(precisions)
    #plot_precision_recall_curve(Unet(),groundtruth_list,predicted_list)
    #plt.show
    #plt.savefig('fuckmu.png')
    
    return precisions,recalls
def get_prec_rec_IoU_accuracy(groundtruth_list, predicted_list,threshold):

    tn, fp, fn, tp = get_confusion_matrix_elements(groundtruth_list, predicted_list)
    
    total = tp + fp + fn + tn
    accuracy = (tp + tn) / total
    prec=tp/(tp+fp)
    rec=tp/(tp+fn)
    IoU=tp/(tp+fp+fn)
    sensitivity =tn / (tn+fp)
    #if(tp == nan and fp == 0):
    #    prec =0
    #print("tp: ",tp)
    #print("fp: ",fp)
#    if ( prec >= threshold ) :
#        tp = tp + fn 
#        fn = 1
#        prec=tp/(tp+fp)
#        rec=tp/(tp+fn)
#    else :
#        fn = tp + fn
#        tp = 1
#        prec=tp/(tp+fp)
#        rec=tp/(tp+fn)

    if np.isnan(rec) == True :
        rec = 0
    if np.isnan(prec) == True :
        prec = 0
    #accuracy = tp
    #prec=tn
    #rec=fp
    #IoU=tp
    return prec,rec,IoU,accuracy,sensitivity





def evalResult(gth_path,npyfile,target_size=(512,512),threshold=0.5,lag_multi_class = False,num_class = 2):
    files=sorted(os.listdir(gth_path))
    #print(type(files))
    #files = [(int(x) for x in files)]
    #files.sort()
    #files = [(str(x) for x in files)]
    #sorted([int(x) for  in files])
    #files = [str(x) for x in files]
    #files.sorted(files)
    #print(files)
    prec=0
    rec=0
    acc=0
    IoU=0
    f1_score=0
    sensitivity=0
    for i,item in enumerate(npyfile):
        img = item[:,:,0]
        gth = io.imread(os.path.join(gth_path,files[i]))
        #print("hhh : ",list(enumerate(npyfile)))
        #print("img: ",img)
        #print("gth: ",i)
        gth = trans.resize(gth,target_size)
        img1=np.array(((img - np.min(img))/np.ptp(img))>0.1).astype(float)
        gth1=np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
        p,r,I,a,f,s=get_validation_metrics(i,gth1,img1,threshold)
        #plot_precision_recall_curve(gth1,img1,threshold)
        prec=prec+p
        rec=rec+r
        acc=acc+a
        IoU=IoU+I
        sensitivity = sensitivity + s 
        f1_score=f1_score+f
        
    print(" Precision=",prec/(i+1),"sensitivity= ", sensitivity/(i+1), "Recall=",rec/(i+1), "IoU=",IoU/(i+1), "acc=",acc/(i+1), "F1=",f1_score/(i+1))  

def get_f1_score(groundtruth_list, predicted_list):

    tn, fp, fn, tp = get_confusion_matrix_elements(groundtruth_list, predicted_list)
    
    f1_score = (2 * tp) / ((2 * tp) + fp + fn)

    return f1_score
def get_validation_metrics(i,groundtruth,predicted,threshold):
    u,v=np.shape(groundtruth)
    groundtruth_list=np.reshape(groundtruth,(u*v,))
    predicted_list=np.reshape(predicted,(u*v,))
    #print(groundtruth_list)
    prec,rec,IoU,acc,sensitivity=get_prec_rec_IoU_accuracy(groundtruth_list, predicted_list,threshold)
    f1_score=get_f1_score(groundtruth_list, predicted_list)
    print("num: ",i,"Prec=",prec, "sensitivity=",sensitivity,"Recall=",rec, "IOU=",IoU, "acc=",acc, "F1=",f1_score)
    #print(f1_score)
    return prec,rec,IoU,acc,f1_score,sensitivity

# %%
def predict_at_threshold(prob, threshold):
    return np.where(prob >= threshold, 1., 0.)

def precision_at_threshold(Y, prob, threshold):
    Y_hat = predict_at_threshold(prob, threshold)
    return np.sum((Y_hat == 1) & (Y == 1)) / np.sum(Y_hat)

def recall_at_threshold(Y, prob, threshold):
    Y_hat = predict_at_threshold(prob, threshold)
    return np.sum((Y_hat == 1) & (Y == 1)) / np.sum(Y)

def precision_recall_curve(Y, prob):
    unique_thresh = np.unique(prob)
    precision = [precision_at_threshold(Y, prob, t) for t in unique_thresh]
    recall = [recall_at_threshold(Y, prob, t) for t in unique_thresh]
    return precision, recall, unique_thresh


#precision, recall, threshold = precision_recall_curve(Y,  lr_model.predict_proba(X)[:, 1])

# %% [markdown]
# ### Train with npy file

# %%
def usnet(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = layers.BatchNormalization()(conv5)
    conv5 = layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = layers.BatchNormalization()(conv5)
    drop5 = layers.Dropout(0.5)(conv5, training=True)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = layers.concatenate([drop4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(conv9)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
def usnet2(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = layers.BatchNormalization()(conv5)
    conv5 = layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = layers.BatchNormalization()(conv5)
    drop5 = layers.Dropout(0.5)(conv5, training=True)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = layers.concatenate([drop4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(conv9)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
def usnet3(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = layers.BatchNormalization()(conv5)
    conv5 = layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = layers.BatchNormalization()(conv5)
    drop5 = layers.Dropout(0.5)(conv5, training=True)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = layers.concatenate([drop4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    newinput =  layers.concatenate([conv9,tempcon9], axis = 3)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
def unetunet(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    ###################
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    
    conv2 = concatenate([conv2,conv8], axis = 3)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    
    conv3 = concatenate([conv3,conv7], axis = 3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    
    conv4 = concatenate([conv4,conv6], axis = 3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    ################
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = conv10)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    smooth = 1.
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [connectloss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
smooth = 1.
def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 
def usnet4(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = layers.concatenate([drop4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    newinput =  layers.concatenate([conv9,tempcon9], axis = 3)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = aspp_block(x, 32)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def iou_coef_only(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return -iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [iou_coef_only], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
smooth = 1.
def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 
def usnet4(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = layers.concatenate([drop4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    newinput =  layers.concatenate([conv9,tempcon9], axis = 3)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = aspp_block(x, 32)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def iou_coef_only(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return -iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [iou_coef_only], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
def usnet4_256(pretrained_weights = None,num_classes = 1,input_size = (256,256,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = layers.concatenate([drop4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    newinput =  layers.concatenate([conv9,tempcon9], axis = 3)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = aspp_block(x, 32)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def iou_coef_only(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return -iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [iou_coef_only], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
smooth = 1.
def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 
def usnet5(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)   
    preconv1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    preconv1 = layers.BatchNormalization()(preconv1)  
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    pool1 = layers.add([pool1,preconv1])
    
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    preconv2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    preconv2 = layers.BatchNormalization()(preconv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    pool2 = layers.add([pool2,preconv2])
    
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    preconv3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    preconv3 = layers.BatchNormalization()(preconv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = layers.add([pool3,preconv3])
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    preconv4 = layers.MaxPooling2D(pool_size=(2, 2))(conv4)
    preconv4 = layers.BatchNormalization()(preconv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)
    pool4 = layers.add([pool4,preconv4])
    
    conv5 = aspp_block(pool4, 512)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    preup6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = layers.concatenate([drop4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    conv6 = layers.add([conv6,preup6])

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    preup7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    conv7 = layers.add([conv7,preup7])

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    preup8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = layers.add([conv8,preup8])

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    preup9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.add([conv9,preup9])
    
    newinput =  layers.concatenate([conv9,tempcon9], axis = 3)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = aspp_block(x, 32)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def iou_coef_only(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return -iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
smooth = 1.
def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 
def usnet6(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)   
    preconv1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    preconv1 = layers.BatchNormalization()(preconv1)  
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    pool1 = layers.add([pool1,preconv1])
    
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    preconv2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    preconv2 = layers.BatchNormalization()(preconv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    pool2 = layers.add([pool2,preconv2])
    
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    preconv3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    preconv3 = layers.BatchNormalization()(preconv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = layers.add([pool3,preconv3])
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    preconv4 = layers.MaxPooling2D(pool_size=(2, 2))(conv4)
    preconv4 = layers.BatchNormalization()(preconv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    #drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = layers.add([pool4,preconv4])
    
    conv5 = aspp_block(pool4, 512)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    preup6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = layers.concatenate([conv4,up6], axis = 3)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    conv6 = layers.add([conv6,preup6])

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    preup7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    conv7 = layers.add([conv7,preup7])

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    preup8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = layers.add([conv8,preup8])

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    preup9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.add([conv9,preup9])
    
    newinput =  layers.concatenate([conv9,tempcon9], axis = 3)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    #x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    #x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    #x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    #x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    #x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    #x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = aspp_block(x, 32)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def iou_coef_only(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return -iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [connectloss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
import datetime
imgs_train,imgs_mask_train = geneTrainNpy("D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/","D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/")
#imgs_train,imgs_mask_train = valGenerator(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args)
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
              tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
              ModelCheckpoint('usnet66_testcrop_tvkloss.hdf5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
#myGene = train2numpy(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args1,save_to_dir = None)
#valdata_image,valdata_mask = valGenerator(2,'data/membrane_hospital_aughand/val','image','label',data_gen_args1)
#model = unet3("test_hope2.hdf5")
#model = usnet2(None,1,(512,512,1))
model = usnet6(None,1,(512,512,1))
#model = unet()


history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
#history=model.fit(imgs_train, imgs_mask_train, steps_per_epoch=200,batch_size=2, epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
#history=model.fit(imgs_train, imgs_mask_train,batch_size=2, epochs=1000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
#history=model.fit((valdata_image,valdata_mask),steps_per_epoch=2000,epochs=1000,validation_data=(valdata_image,valdata_mask),

#                            callbacks=[mycallback])

#history=model.fit(myGene,steps_per_epoch=2000,epochs=1000,validation_data=(valdata_image,valdata_mask),
#                           callbacks=[mycallback])
#tensorboard --logdir logs
# Out:
# ['D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_0.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_100.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1000.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1001.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1002.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1003.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1004.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1005.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1006.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1007.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1008.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1009.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_101.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1010.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1011.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1012.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1013.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1014.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1015.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1016.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1017.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1018.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1019.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_102.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1020.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1021.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1022.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1023.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1024.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1025.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1026.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1027.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1028.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1029.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_103.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1030.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1031.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1032.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1033.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1034.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1035.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1036.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1037.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1038.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1039.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_104.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1040.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1041.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1042.png', 'D:/Alldata/ddsm_hospital_inbreast ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6844/4030883462.py in <module>
#       1 import datetime
# ----> 2 imgs_train,imgs_mask_train = geneTrainNpy("D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/","D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/")
#       3 #imgs_train,imgs_mask_train = valGenerator(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args)
#       4 log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#       5 mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#
# ~\Desktop\unet-master\data.py in geneTrainNpy(image_path, mask_path, flag_multi_class, num_class, image_prefix, mask_prefix, image_as_gray, mask_as_gray)
#     171         mask = io.imread(item.replace(image_path,mask_path).replace(image_prefix,mask_prefix),as_gray = mask_as_gray)
#     172         mask = np.reshape(mask,mask.shape + (1,)) if mask_as_gray else mask
# --> 173         img,mask = adjustData(img,mask,flag_multi_class,num_class)
#     174         image_arr.append(img)
#     175         mask_arr.append(mask)
#
# ~\Desktop\unet-master\data.py in adjustData(img, mask, flag_multi_class, num_class)
#      39     elif(np.max(img) > 1):
#      40         img = img / 255
# ---> 41         mask = mask /255
#      42         mask[mask > 0.5] = 1
#      43         mask[mask <= 0.5] = 0
#
# KeyboardInterrupt:

# %%
smooth = 1.
def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 
def newnet(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = layers.BatchNormalization()(conv4)
    conv4 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = layers.BatchNormalization()(conv4)
    #drop4 = layers.Dropout(0.5)(conv4, training=True)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = aspp_block(pool4, 512)

    up6 = layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = layers.concatenate([aspp_block(conv4, 256),up6], axis = 3)
    del conv4
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = layers.concatenate([conv3,up7], axis = 3)
    del conv3
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = layers.concatenate([conv2,up8], axis = 3)
    del conv2
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = layers.concatenate([conv1,up9], axis = 3)
    del conv1
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    newinput =  layers.concatenate([conv9,tempcon9], axis = 3)
    del conv9
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = aspp_block(x, 32)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def iou_coef_only(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return -iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [connectloss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
import datetime

imgs_train,imgs_mask_train = geneTrainNpy("D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/","D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/")
# Out:
# ['D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_0.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_100.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1000.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10000.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10001.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10002.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10003.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10004.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10005.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10006.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10007.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10008.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10009.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1001.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10010.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10011.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10012.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10013.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10014.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10015.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10016.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10017.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10018.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10019.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1002.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10020.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10021.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10022.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10023.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10024.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10025.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10026.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10027.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10028.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10029.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1003.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10030.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10031.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10032.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10033.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10034.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10035.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10036.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10037.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10038.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10039.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1004.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10040.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_ ...

# %%
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
              tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
              ModelCheckpoint('usnet4_inbreast_hospital_ddsm_clahe_iouloss.hdf5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
#myGene = train2numpy(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args1,save_to_dir = None)
#valdata_image,valdata_mask = valGenerator(2,'data/membrane_hospital_aughand/val','image','label',data_gen_args1)
#model = unet3("test_hope2.hdf5")
#model = usnet2(None,1,(512,512,1))
model = usnet4()
#model = unet()
#usnet4_ddsm_iouloss

history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15796/4160119596.py in <module>
# ----> 1 log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#       2 mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#       3               tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
#       4               ModelCheckpoint('usnet4_inbreast_hospital_ddsm_clahe_iouloss.hdf5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
#       5 #myGene = train2numpy(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args1,save_to_dir = None)
#
# NameError: name 'datetime' is not defined

# %%
model = usnet4()
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 512, 512, 64) 640         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 512, 512, 64) 256         conv2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 512, 512, 64) 36928       batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 512, 512, 64) 256         conv2d_117[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 256, 256, 64) 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 256, 256, 128 73856       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 256, 256, 128 512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 256, 256, 128 147584      batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 256, 256, 128 512         conv2d_119[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 128 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 128, 128, 256 295168      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 128, 128, 256 1024        conv2d_120[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 128, 128, 256 590080      batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 128, 128, 256 1024        conv2d_121[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 64, 64, 256)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 64, 64, 512)  1180160     max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 64, 64, 512)  2048        conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 64, 64, 512)  2359808     batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 64, 64, 512)  2048        conv2d_123[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 512)  0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 512)  0           dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 32, 32, 512)  2359808     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 32, 32, 512)  2359808     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 32, 32, 512)  2359808     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 32, 32, 512)  2359808     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 32, 32, 512)  2048        conv2d_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 32, 32, 512)  2048        conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 32, 32, 512)  2048        conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 32, 32, 512)  2048        conv2d_127[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 512)  0           batch_normalization_90[0][0]
#                                                                  batch_normalization_91[0][0]
#                                                                  batch_normalization_92[0][0]
#                                                                  batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 32, 32, 512)  262656      add_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 64, 64, 512)  0           conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 64, 64, 512)  1049088     up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 64, 64, 1024) 0           dropout_14[0][0]
#                                                                  conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 64, 64, 512)  4719104     concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 64, 64, 512)  2359808     conv2d_130[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 128, 128, 512 0           conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 128, 128, 256 524544      up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 128, 128, 512 0           batch_normalization_87[0][0]
#                                                                  conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 128, 128, 256 1179904     concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 128, 128, 256 590080      conv2d_133[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 256, 256, 256 0           conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 256, 256, 128 131200      up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 256, 256, 256 0           batch_normalization_85[0][0]
#                                                                  conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 256, 256, 128 295040      concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 256, 256, 128 147584      conv2d_136[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 512, 512, 128 0           conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 512, 512, 64) 32832       up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 512, 512, 128 0           batch_normalization_83[0][0]
#                                                                  conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 512, 512, 64) 73792       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 512, 512, 64) 36928       conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 512, 512, 64) 36928       conv2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 512, 512, 64) 36928       conv2d_139[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 512, 512, 128 0           conv2d_142[0][0]
#                                                                  conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 512, 512, 64) 73792       concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 512, 512, 64) 256         conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 512, 512, 64) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 512, 512, 64) 36928       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 512, 512, 64) 256         conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 512, 512, 64) 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_indices2d_10 ( [(None, 256, 256, 64 0           activation_51[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 256, 256, 192 0           max_pooling_with_indices2d_10[0][
#                                                                  conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 256, 256, 128 221312      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 256, 256, 128 512         conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 256, 256, 128 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 256, 256, 128 147584      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 256, 256, 128 512         conv2d_146[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 256, 256, 128 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_indices2d_11 ( [(None, 128, 128, 12 0           activation_53[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 128, 128, 384 0           max_pooling_with_indices2d_11[0][
#                                                                  conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 128, 128, 256 884992      concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 128, 128, 256 1024        conv2d_147[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 128, 128, 256 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 128, 128, 256 590080      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 128, 128, 256 1024        conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 128, 128, 256 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 128, 128, 256 590080      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 128, 128, 256 1024        conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 128, 128, 256 0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_indices2d_12 ( [(None, 64, 64, 256) 0           activation_56[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 256)  0           max_pooling_with_indices2d_12[0][
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 64, 64, 768)  0           dropout_15[0][0]
#                                                                  conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 64, 64, 512)  3539456     concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 64, 64, 512)  2048        conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 64, 64, 512)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 64, 64, 512)  2359808     activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 64, 64, 512)  2048        conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 64, 64, 512)  0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 64, 64, 512)  2359808     activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 64, 64, 512)  2048        conv2d_152[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 64, 64, 512)  0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_indices2d_13 ( [(None, 32, 32, 512) 0           activation_59[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32, 32, 512)  0           max_pooling_with_indices2d_13[0][
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 32, 32, 512)  2359808     dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 32, 32, 512)  2048        conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 512)  0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 32, 32, 512)  2359808     activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 32, 32, 512)  2048        conv2d_154[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 512)  0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 32, 32, 512)  2359808     activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 32, 32, 512)  2048        conv2d_155[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 512)  0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_indices2d_14 ( [(None, 16, 16, 512) 0           activation_62[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 16, 16, 512)  0           max_pooling_with_indices2d_14[0][
# __________________________________________________________________________________________________
# max_unpooling_with_indices2d_10 (None, 32, 32, 512)  0           dropout_17[0][0]
#                                                                  max_pooling_with_indices2d_14[0][
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 32, 32, 512)  2359808     max_unpooling_with_indices2d_10[0
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 32, 32, 512)  2048        conv2d_156[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 512)  0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 32, 32, 512)  2359808     activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 32, 32, 512)  2048        conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 512)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 32, 32, 512)  2359808     activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 32, 32, 512)  2048        conv2d_158[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 512)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 32, 32, 512)  0           activation_65[0][0]
# __________________________________________________________________________________________________
# max_unpooling_with_indices2d_11 (None, 64, 64, 512)  0           dropout_18[0][0]
#                                                                  max_pooling_with_indices2d_13[0][
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 64, 64, 512)  2359808     max_unpooling_with_indices2d_11[0
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 64, 64, 512)  2048        conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 64, 64, 512)  0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 64, 64, 512)  2359808     activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 64, 64, 512)  2048        conv2d_160[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 64, 64, 512)  0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 64, 64, 256)  1179904     activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 64, 64, 256)  1024        conv2d_161[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 64, 64, 256)  0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 64, 64, 256)  0           activation_68[0][0]
# __________________________________________________________________________________________________
# max_unpooling_with_indices2d_12 (None, 128, 128, 256 0           dropout_19[0][0]
#                                                                  max_pooling_with_indices2d_12[0][
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 128, 128, 256 590080      max_unpooling_with_indices2d_12[0
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 128, 128, 256 1024        conv2d_162[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 128, 128, 256 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 128, 128, 256 590080      activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 128, 128, 256 1024        conv2d_163[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 128, 128, 256 0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 128, 128, 128 295040      activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 128, 128, 128 512         conv2d_164[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 128, 128, 128 0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 128, 128, 128 0           activation_71[0][0]
# __________________________________________________________________________________________________
# max_unpooling_with_indices2d_13 (None, 256, 256, 128 0           dropout_20[0][0]
#                                                                  max_pooling_with_indices2d_11[0][
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 256, 256, 128 147584      max_unpooling_with_indices2d_13[0
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 256, 256, 128 512         conv2d_165[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 256, 256, 128 0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 256, 256, 64) 73792       activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 256, 256, 64) 256         conv2d_166[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 256, 256, 64) 0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# max_unpooling_with_indices2d_14 (None, 512, 512, 64) 0           activation_73[0][0]
#                                                                  max_pooling_with_indices2d_10[0][
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 512, 512, 64) 36928       max_unpooling_with_indices2d_14[0
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 512, 512, 64) 256         conv2d_167[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 512, 512, 64) 0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 512, 512, 32) 18464       activation_74[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 512, 512, 32) 18464       activation_74[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 512, 512, 32) 18464       activation_74[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 512, 512, 32) 18464       activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 512, 512, 32) 128         conv2d_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 512, 512, 32) 128         conv2d_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 512, 512, 32) 128         conv2d_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 512, 512, 32) 128         conv2d_171[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 512, 512, 32) 0           batch_normalization_119[0][0]
#                                                                  batch_normalization_120[0][0]
#                                                                  batch_normalization_121[0][0]
#                                                                  batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 512, 512, 32) 1056        add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 512, 512, 1)  33          conv2d_172[0][0]
# ==================================================================================================
# Total params: 58,318,657
# Trainable params: 58,294,593
# Non-trainable params: 24,064
# __________________________________________________________________________________________________

# %%
from __future__ import print_function

import os, glob
from skimage.io import imsave
import numpy as np
import tensorflow as tf
#from keras.optimizers import Adam
#from keras.callbacks import ModelCheckpoint
#from keras import backend as K                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   00

#from keras.preprocessing.image import ImageDataGenerator
#import matplotlib.pyplot as plt
#from data import load_train_data, load_test_data
#from sklearn.model_selection import train_test_split
#K.set_image_data_format('channels_last')  # TF dimension ordering in this code



smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def focal_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    BCE = K.binary_crossentropy(y_true_f, y_pred_f)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(0.8 * K.pow((1-BCE_EXP), 2.) * BCE)
    return focal_loss


def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)


def loss(y_true, y_pred):
    return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 

def get_wnet(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    ##################################
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    
    conv2 = concatenate([conv2,conv8], axis = 3)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    
    conv3 = concatenate([conv3,conv7], axis = 3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    
    conv4 = concatenate([conv4,conv6], axis = 3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    ################
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = conv10)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    smooth = 1.
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [connectloss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %% [markdown]
# 論文用

# %%
from __future__ import print_function

import os, glob
from skimage.io import imsave
import numpy as np
import tensorflow as tf
#from keras.optimizers import Adam
#from keras.callbacks import ModelCheckpoint
#from keras import backend as K
#from keras.preprocessing.image import ImageDataGenerator
#import matplotlib.pyplot as plt
#from data import load_train_data, load_test_data
#from sklearn.model_selection import train_test_split
#K.set_image_data_format('channels_last')  # TF dimension ordering in this code



smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def focal_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    BCE = K.binary_crossentropy(y_true_f, y_pred_f)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(0.8 * K.pow((1-BCE_EXP), 2.) * BCE)
    return focal_loss


def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)


def loss(y_true, y_pred):
    return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 

def get_wnet666(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)    
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = BatchNormalization()(conv8)

    up9 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = BatchNormalization()(conv9)
   
   
    ##################################

    conv1 = concatenate([Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv9),conv9], axis = 3)
    #conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)    
    conv2 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv2 = BatchNormalization()(conv2)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv2 = concatenate([Conv2D(64, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(pool1),conv8], axis = 3)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv3 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv3 = BatchNormalization()(conv3)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv3 = concatenate([Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2),conv7], axis = 3)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv4 = BatchNormalization()(conv4)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    conv4 = concatenate([Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3),conv6], axis = 3)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    conv6 = BatchNormalization()(conv6)

    up7 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    conv7 = BatchNormalization()(conv7)

    up8 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = BatchNormalization()(conv8)

    up9 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    ################
    conv10 = aspp_block(conv9, 32)
    
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv10)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = conv10)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    smooth = 1.
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [connectloss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
from __future__ import print_function

import os, glob
from skimage.io import imsave
import numpy as np
import tensorflow as tf
#from keras.optimizers import Adam
#from keras.callbacks import ModelCheckpoint
#from keras import backend as K
#from keras.preprocessing.image import ImageDataGenerator
#import matplotlib.pyplot as plt
#from data import load_train_data, load_test_data
#from sklearn.model_selection import train_test_split
#K.set_image_data_format('channels_last')  # TF dimension ordering in this code



smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def focal_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    BCE = K.binary_crossentropy(y_true_f, y_pred_f)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(0.8 * K.pow((1-BCE_EXP), 2.) * BCE)
    return focal_loss


def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)


def loss(y_true, y_pred):
    return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 

def get_wnet666(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    #drop4 = Dropout(0.5)(conv4, training=True)    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = BatchNormalization()(conv8)

    up9 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = BatchNormalization()(conv9)
   
   
    ##################################

    conv1 = concatenate([Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv9),conv9], axis = 3)
    #conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)    
    conv2 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv2 = BatchNormalization()(conv2)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv2 = concatenate([Conv2D(64, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(pool1),conv8], axis = 3)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv3 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv3 = BatchNormalization()(conv3)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv3 = concatenate([Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2),conv7], axis = 3)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv4 = BatchNormalization()(conv4)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    conv4 = concatenate([Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3),conv6], axis = 3)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    conv6 = BatchNormalization()(conv6)

    up7 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    conv7 = BatchNormalization()(conv7)

    up8 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = BatchNormalization()(conv8)

    up9 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    ################
    conv10 = aspp_block(conv9, 32)
    
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv10)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = conv10)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    smooth = 1.
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [connectloss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
import datetime
imgs_train,imgs_mask_train = geneTrainNpy("D:/Alldata/inbreast_ddsm/croponly/train/traincomb/","D:/Alldata/inbreast_ddsm/croponly/train/traincomb/")
#imgs_train,imgs_mask_train = valGenerator(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args)
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
              tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
              ModelCheckpoint('wnetnn_testcrop_newloss.h5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
#myGene = train2numpy(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args1,save_to_dir = None)
#valdata_image,valdata_mask = valGenerator(2,'data/membrane_hospital_aughand/val','image','label',data_gen_args1)
#model = unet3("test_hope2.hdf5")
#model = usnet2(None,1,(512,512,1))
model = get_wnet666(None,1,(512,512,1))
#model = unet()
history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
# Out:
# ['D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_0.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_10.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_100.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1000.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1001.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1002.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1003.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1004.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1005.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1006.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1007.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1008.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1009.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_101.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1010.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1011.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1012.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1013.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1014.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1015.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1016.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1017.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1018.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1019.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_102.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1020.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1021.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1022.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1023.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1024.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1025.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1026.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1027.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1028.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1029.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_103.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1030.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1031.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1032.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1033.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1034.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1035.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1036.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1037.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1038.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1039.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_104.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1040.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1041.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1042.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1043.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1044.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1045.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1046.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1047.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1048.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1049.png', 'D:/Alldat ...
# Epoch 1/5000
#    1/2832 [..............................] - ETA: 0s - loss: -0.2045 - accuracy: 0.4924WARNING:tensorflow:From C:\Users\414\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/2832 [..............................] - ETA: 17:15 - loss: -0.2558 - accuracy: 0.5334WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0419s vs `on_train_batch_begin` time: 0.0708s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0419s vs `on_train_batch_end` time: 0.6183s). Check your callbacks.
# 2832/2832 [==============================] - ETA: 0s - loss: -0.6594 - accuracy: 0.8614WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_test_batch_end` time: 0.0947s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to -0.63952, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 855s 302ms/step - loss: -0.6594 - accuracy: 0.8614 - val_loss: -0.6395 - val_accuracy: 0.8796
# Epoch 2/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7137 - accuracy: 0.8890
# Epoch 00002: val_loss did not improve from -0.63952
# 2832/2832 [==============================] - 856s 302ms/step - loss: -0.7137 - accuracy: 0.8890 - val_loss: -0.6118 - val_accuracy: 0.8482
# Epoch 3/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7287 - accuracy: 0.8956
# Epoch 00003: val_loss improved from -0.63952 to -0.65512, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 856s 302ms/step - loss: -0.7287 - accuracy: 0.8956 - val_loss: -0.6551 - val_accuracy: 0.8768
# Epoch 4/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7396 - accuracy: 0.9004
# Epoch 00004: val_loss improved from -0.65512 to -0.66428, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 856s 302ms/step - loss: -0.7396 - accuracy: 0.9004 - val_loss: -0.6643 - val_accuracy: 0.8919
# Epoch 5/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7440 - accuracy: 0.9021
# Epoch 00005: val_loss improved from -0.66428 to -0.69270, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 858s 303ms/step - loss: -0.7440 - accuracy: 0.9021 - val_loss: -0.6927 - val_accuracy: 0.9008
# Epoch 6/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7514 - accuracy: 0.9047
# Epoch 00006: val_loss did not improve from -0.69270
# 2832/2832 [==============================] - 853s 301ms/step - loss: -0.7514 - accuracy: 0.9047 - val_loss: -0.6797 - val_accuracy: 0.8894
# Epoch 7/5000
#  769/2832 [=======>......................] - ETA: 9:38 - loss: -0.7514 - accuracy: 0.9050
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17748/3828042892.py in <module>
#      12 model = get_wnet666(None,1,(512,512,1))
#      13 #model = unet()
# ---> 14 history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
# --> 345           numpy_logs = tf_utils.to_numpy_or_python_type(logs)
#     346         hook(batch, numpy_logs)
#     347
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\tf_utils.py in to_numpy_or_python_type(tensors)
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#     536
# --> 537   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     538
#     539
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     531   def _to_single_numpy_or_python_type(t):
#     532     if isinstance(t, ops.Tensor):
# --> 533       x = t.numpy()
#     534       return x.item() if np.ndim(x) == 0 else x
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1061     """
#    1062     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1063     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1064     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1065
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1027   def _numpy(self):
#    1028     try:
# -> 1029       return self._numpy_internal()
#    1030     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1031       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
              tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
              ModelCheckpoint('wnetnn_testcrop_newloss.hdf5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
#myGene = train2numpy(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args1,save_to_dir = None)
#valdata_image,valdata_mask = valGenerator(2,'data/membrane_hospital_aughand/val','image','label',data_gen_args1)
#model = unet3("test_hope2.hdf5")
#model = usnet2(None,1,(512,512,1))
model = get_wnet666(None,1,(512,512,1))
#model = unet()
history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
# Out:
# Epoch 1/5000
#    2/2832 [..............................] - ETA: 50:04 - loss: -0.3896 - accuracy: 0.5402WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0180s vs `on_train_batch_end` time: 2.1054s). Check your callbacks.
# 2832/2832 [==============================] - ETA: 0s - loss: -0.6587 - accuracy: 0.8615WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_test_batch_end` time: 0.0877s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to -0.64794, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 833s 294ms/step - loss: -0.6587 - accuracy: 0.8615 - val_loss: -0.6479 - val_accuracy: 0.8823
# Epoch 2/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7137 - accuracy: 0.8887
# Epoch 00002: val_loss improved from -0.64794 to -0.65216, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 833s 294ms/step - loss: -0.7137 - accuracy: 0.8887 - val_loss: -0.6522 - val_accuracy: 0.8969
# Epoch 3/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7310 - accuracy: 0.8964
# Epoch 00003: val_loss improved from -0.65216 to -0.68239, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 832s 294ms/step - loss: -0.7310 - accuracy: 0.8964 - val_loss: -0.6824 - val_accuracy: 0.9032
# Epoch 4/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7385 - accuracy: 0.8995
# Epoch 00004: val_loss improved from -0.68239 to -0.70246, saving model to wnetnn_testcrop_newloss.hdf5
# 2832/2832 [==============================] - 833s 294ms/step - loss: -0.7385 - accuracy: 0.8995 - val_loss: -0.7025 - val_accuracy: 0.9108
# Epoch 5/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7458 - accuracy: 0.9030
# Epoch 00005: val_loss did not improve from -0.70246
# 2832/2832 [==============================] - 832s 294ms/step - loss: -0.7458 - accuracy: 0.9030 - val_loss: -0.7000 - val_accuracy: 0.9127
# Epoch 6/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7522 - accuracy: 0.9054
# Epoch 00006: val_loss did not improve from -0.70246
# 2832/2832 [==============================] - 832s 294ms/step - loss: -0.7522 - accuracy: 0.9054 - val_loss: -0.5732 - val_accuracy: 0.7963
# Epoch 7/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7556 - accuracy: 0.9069
# Epoch 00007: val_loss did not improve from -0.70246
# 2832/2832 [==============================] - 832s 294ms/step - loss: -0.7556 - accuracy: 0.9069 - val_loss: -0.6955 - val_accuracy: 0.9023
# Epoch 8/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7608 - accuracy: 0.9089
# Epoch 00008: val_loss did not improve from -0.70246
# 2832/2832 [==============================] - 832s 294ms/step - loss: -0.7608 - accuracy: 0.9089 - val_loss: -0.7019 - val_accuracy: 0.9050
# Epoch 9/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7621 - accuracy: 0.9097
# Epoch 00009: val_loss did not improve from -0.70246
# 2832/2832 [==============================] - 832s 294ms/step - loss: -0.7621 - accuracy: 0.9097 - val_loss: -0.6746 - val_accuracy: 0.8938
# Epoch 10/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.7657 - accuracy: 0.9111
# Epoch 00010: val_loss did not improve from -0.70246
# 2832/2832 [==============================] - 833s 294ms/step - loss: -0.7657 - accuracy: 0.9111 - val_loss: -0.6956 - val_accuracy: 0.9069
# Epoch 11/5000
#  307/2832 [==>...........................] - ETA: 11:29 - loss: -0.7703 - accuracy: 0.9145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12888/196223043.py in <module>
#       9 model = get_wnet666(None,1,(512,512,1))
#      10 #model = unet()
# ---> 11 history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
# --> 345           numpy_logs = tf_utils.to_numpy_or_python_type(logs)
#     346         hook(batch, numpy_logs)
#     347
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\tf_utils.py in to_numpy_or_python_type(tensors)
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#     536
# --> 537   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     538
#     539
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     531   def _to_single_numpy_or_python_type(t):
#     532     if isinstance(t, ops.Tensor):
# --> 533       x = t.numpy()
#     534       return x.item() if np.ndim(x) == 0 else x
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1061     """
#    1062     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1063     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1064     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1065
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1027   def _numpy(self):
#    1028     try:
# -> 1029       return self._numpy_internal()
#    1030     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1031       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
smooth = 1.
def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y 
    
   
   
    
def usnet666(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    #drop4 = Dropout(0.5)(conv4, training=True)    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = BatchNormalization()(conv8)

    up9 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = BatchNormalization()(conv9)
    ##########
    newinput = concatenate([Conv2D(32, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv9),conv9], axis = 3)
    x = layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(newinput)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_1 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv8], axis = 3)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)    
    x, mask_2 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)

    x = layers.concatenate([x,conv7], axis = 3)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_3 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    #x = layers.Dropout(0.5)(x)

    x = layers.concatenate([x,conv6], axis = 3)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_4 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    #x = layers.Dropout(0.5)(x)

    
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x, mask_5 = MaxPoolingWithIndices2D(pool_size=(2, 2))(x)
    #x = layers.Dropout(0.5)(x)
    
    # decoder
    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_5])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    #x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_4])
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    #x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_3])
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    #x = layers.Dropout(0.5)(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_2])
    x = layers.Convolution2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Convolution2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = MaxUnpoolingWithIndices2D((2, 2))([x, mask_1])
    x = layers.Convolution2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = aspp_block(x, 32)
    xoutputs = layers.Conv2D(num_classes, (1, 1), padding='valid',activation=relu_advanced, kernel_initializer='he_uniform')(x)
    
    #conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    #conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = xoutputs)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def iou_coef_only(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return -iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [iou_coef_only], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

# %%
import datetime
imgs_train,imgs_mask_train = geneTrainNpy("D:/Alldata/inbreast_ddsm/croponly/train/traincomb2/","D:/Alldata/inbreast_ddsm/croponly/train/traincomb2/")
#imgs_train,imgs_mask_train = valGenerator(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args)
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
              tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
              ModelCheckpoint('usnet666_testcrop_newloss.hdf5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
#myGene = train2numpy(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args1,save_to_dir = None)
#valdata_image,valdata_mask = valGenerator(2,'data/membrane_hospital_aughand/val','image','label',data_gen_args1)
#model = unet3("test_hope2.hdf5")
#model = usnet2(None,1,(512,512,1))
##model = usnet666(None,1,(512,512,1))
#model = unet()
##history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
# Out:
# ['D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_0.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_10.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_100.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1000.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1001.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1002.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1003.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1004.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1005.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1006.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1007.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1008.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1009.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_101.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1010.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1011.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1012.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1013.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1014.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1015.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1016.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1017.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1018.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1019.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_102.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1020.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1021.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1022.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1023.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1024.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1025.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1026.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1027.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1028.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1029.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_103.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1030.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1031.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1032.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1033.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1034.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1035.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1036.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1037.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1038.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1039.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_104.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1040.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1041.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1042.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1043.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1044.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1045.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1046.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1047.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1048.png', 'D:/Alldata/inbreast_ddsm/croponly/train/traincomb\\image_1049.png', 'D:/Alldat ...

# %%
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
              tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
              ModelCheckpoint('usnet666_testcrop_iouloss.hdf5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
model = usnet666(None,1,(512,512,1))
#model = unet()
history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer MaxPoolingWithIndices2D has arguments in `__init__` and therefore must override `get_config`.
# Epoch 1/5000
#    2/2832 [..............................] - ETA: 1:23:07 - loss: -0.1676 - accuracy: 0.5478WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1426s vs `on_train_batch_end` time: 3.3820s). Check your callbacks.
# 2832/2832 [==============================] - ETA: 0s - loss: -0.5748 - accuracy: 0.8450
# Epoch 00001: val_loss improved from inf to -0.53948, saving model to usnet666_testcrop_iouloss.hdf5
# 2832/2832 [==============================] - 855s 302ms/step - loss: -0.5748 - accuracy: 0.8450 - val_loss: -0.5395 - val_accuracy: 0.8664
# Epoch 2/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.6169 - accuracy: 0.8695
# Epoch 00002: val_loss did not improve from -0.53948
# 2832/2832 [==============================] - 854s 302ms/step - loss: -0.6169 - accuracy: 0.8695 - val_loss: -0.5114 - val_accuracy: 0.8429
# Epoch 3/5000
# 2832/2832 [==============================] - ETA: 0s - loss: -0.6497 - accuracy: 0.8839
# Epoch 00003: val_loss improved from -0.53948 to -0.61594, saving model to usnet666_testcrop_iouloss.hdf5
# 2832/2832 [==============================] - 843s 298ms/step - loss: -0.6497 - accuracy: 0.8839 - val_loss: -0.6159 - val_accuracy: 0.8939
# Epoch 4/5000
# 2110/2832 [=====================>........] - ETA: 3:14 - loss: -0.6605 - accuracy: 0.8882

# %%
def get_wnet2(pretrained_weights = None,num_classes = 1,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    tempcon9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    ##################################
    newinput = concatenate([conv9,tempcon9], axis = 3)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(newinput)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    
    conv2 = concatenate([conv2,conv8], axis = 3)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    
    conv3 = concatenate([conv3,conv7], axis = 3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    
    conv4 = concatenate([conv4,conv6], axis = 3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = aspp_block(pool4, 512)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    ################
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    #conv10 = Conv2D(1, 1)(conv9)
    
    model = tf.keras.Model(inputs = inputs, outputs = conv10)
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    import os 
    os.environ['KERAS_BACKEND']='tensorflow'
    import tensorflow.python.keras.backend as K
    smooth = 1.
    def dice_coef(y_true, y_pred, smooth=1):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    def dice_loss(y_true, y_pred):
        loss = 1 - dice_coef(y_true, y_pred)
        return loss
    
    def dice_coef_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    def FocalTverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, gamma=GAMMA, smooth=1e-6):
    
        #flatten label and prediction tensors
        inputs = K.flatten(inputs)
        targets = K.flatten(targets)
        
        #True Positives, False Positives & False Negatives
        TP = K.sum((inputs * targets))
        FP = K.sum(((1-targets) * inputs))
        FN = K.sum((targets * (1-inputs)))
               
        Tversky = (TP + smooth) / (TP + alpha*FP + beta*FN + smooth)  
        FocalTversky = K.pow((1 - Tversky), gamma)
        
        return FocalTversky
    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def iou_coef(y_true, y_pred, smooth=1):
        intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
        union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
        iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
        return iou
    def connectloss(y_true, y_pred):
        return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))
    #model.compile(optimizer = Adam(lr = 1e-6), loss = 'binary_crossentropy', metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(loss='mse',optimizer=Adam(lr = 1e-5),metrics='metric_fun')
    model.compile(optimizer = Adam(lr = 1e-4), loss = [connectloss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_coef_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [FocalTverskyLoss], metrics = 'accuracy')
    #model.compile(optimizer = sgd(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'accuracy')binary_accuracy、dice_coef
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [dice_loss], metrics = 'binary_accuracy')
    #model.compile(optimizer = Adam(lr = 1e-6), loss = [categorical_crossentropy], metrics = 'categorical_crossentropy')
    if(pretrained_weights):
    	model= load_model(pretrained_weights)
    
    return model

import datetime
imgs_train,imgs_mask_train = geneTrainNpy("D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/","D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb/")
#imgs_train,imgs_mask_train = valGenerator(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args)
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
mycallback = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
              tf.keras.callbacks.EarlyStopping(patience=20, monitor = 'val_loss'),
              ModelCheckpoint('wnet2_testallcrop_newloss.hdf5', monitor='val_loss',verbose=1, save_weights_only=True, save_best_only=True)]
#myGene = train2numpy(2,'data/membrane_hospital_aughand/train','image','label',data_gen_args1,save_to_dir = None)
#valdata_image,valdata_mask = valGenerator(2,'data/membrane_hospital_aughand/val','image','label',data_gen_args1)
#model = unet3("test_hope2.hdf5")
#model = usnet2(None,1,(512,512,1))
model = get_wnet2(None,1,(512,512,1))
#model = unet()
history=model.fit(imgs_train, imgs_mask_train,batch_size=2,epochs=5000,verbose=1,validation_split=0.2, shuffle=True, callbacks=[mycallback])
# Out:
# ['D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_0.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_10.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_100.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1000.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1001.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1002.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1003.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1004.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1005.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1006.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1007.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1008.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1009.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_101.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1010.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1011.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1012.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1013.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1014.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1015.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1016.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1017.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1018.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1019.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_102.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1020.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1021.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1022.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1023.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1024.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1025.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1026.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1027.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1028.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1029.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_103.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1030.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1031.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1032.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1033.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1034.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1035.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1036.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1037.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1038.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1039.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_104.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1040.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1041.png', 'D:/Alldata/ddsm_hospital_inbreast/croponly/train/traincomb\\image_1042.png', 'D:/Alldata/ddsm_hospital_inbreast ...
# Epoch 1/5000
#    1/2515 [..............................] - ETA: 0s - loss: -0.1902 - accuracy: 0.8037WARNING:tensorflow:From C:\Users\414\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/2515 [..............................] - ETA: 12:24 - loss: -0.2639 - accuracy: 0.7178WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1736s vs `on_train_batch_end` time: 0.4169s). Check your callbacks.
# 2515/2515 [==============================] - ETA: 0s - loss: -0.4207 - accuracy: 0.8547WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_test_batch_end` time: 0.1596s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to -0.41333, saving model to wnet2_testallcrop_newloss.hdf5
# 2515/2515 [==============================] - 1440s 572ms/step - loss: -0.4207 - accuracy: 0.8547 - val_loss: -0.4133 - val_accuracy: 0.8726
# Epoch 2/5000
# 2515/2515 [==============================] - ETA: 0s - loss: -0.4861 - accuracy: 0.8820
# Epoch 00002: val_loss improved from -0.41333 to -0.45144, saving model to wnet2_testallcrop_newloss.hdf5
# 2515/2515 [==============================] - 1480s 589ms/step - loss: -0.4861 - accuracy: 0.8820 - val_loss: -0.4514 - val_accuracy: 0.8964
# Epoch 3/5000
# 2125/2515 [========================>.....] - ETA: 3:27 - loss: -0.5255 - accuracy: 0.8898

# %% [markdown]
# # 準備npy所需資料

# %%
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand/train/temp/image/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files

i=0

for file_name in filename_list:
    img_name_temp = "image_"+str(i)+".jpg"
    file_oldname_image = os.path.join("./data/membrane_hospital_aughand/train/temp/image/", file_name)
    file_newname_image = os.path.join("./data/membrane_hospital_aughand/train/temp/image/", img_name_temp)
    
    os.rename(file_oldname_image, file_newname_image)
    mask_name_temp = "mask_"+str(i)+".jpg"
    file_oldname_mask = os.path.join("./data/membrane_hospital_aughand/train/temp/label/", file_name)
    file_newname_mask = os.path.join("./data/membrane_hospital_aughand/train/temp/label/", mask_name_temp)
    os.rename(file_oldname_mask, file_newname_mask)
    i=i+1

# %%
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand/train/image/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files

i=0

for file_name in filename_list:
    img_name_temp = str(i)+".jpg"
    file_oldname_image = os.path.join("./data/membrane_hospital_aughand/train/image/", file_name)
    file_newname_image = os.path.join("./data/membrane_hospital_aughand/train/image/", img_name_temp)
    
    os.rename(file_oldname_image, file_newname_image)
    i=i+1

# %%
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand/train/aug1/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:
    img_name_temp = file_name.split(".jpg")
    im = Image.open("./data/membrane_hospital_aughand/train/aug1/"+file_name)
    im.save("./data/membrane_hospital_aughand/train/aug/"+img_name_temp[0]+".png")

# %%
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand/train/aug_new/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:
    #img_name_temp = file_name.split(".jpg")
    im = Image.open("./data/membrane_hospital_aughand/train/aug_new/"+file_name)
    new_img = im.resize((512, 512))
    new_img.save("./data/membrane_hospital_aughand/train/aug_resize/"+file_name)

# %% [markdown]
# ### test your model and save predicted results

# %%
testGene = testGenerator("data/membrane_hospital_aughand_fakeadd/test/")#cropcom、membrane_hospital_aughand_fake、membrane_hospital_aughand_ddsm、membrane_hospital_aughand_inbreast
model = usnet4()
model.load_weights("usnet4_testcrop5_iouloss.hdf5")
#model.load_weights("un/et_fake.hdf5")

#model.load_weights("C:/Users/414/Desktop/trainresult/1205.hdf5")

results = model.predict_generator(testGene,48,verbose=1)
saveResult("data/membrane_hospital_aughand_fakeadd/test/pred/",results)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5304/3542742736.py in <module>
#       6 #model.load_weights("C:/Users/414/Desktop/trainresult/1205.hdf5")
#       7
# ----> 8 results = model.predict_generator(testGene,48,verbose=1)
#       9 saveResult("data/membrane_hospital_aughand_fakeadd/test/pred/",results)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in predict_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1874     """
#    1875     _keras_api_gauge.get_cell('predict_generator').set(True)
# -> 1876     return self.predict(
#    1877         generator,
#    1878         steps=steps,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
#    1600             if data_handler.should_sync:
#    1601               context.async_wait()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     844               *args, **kwds)
#     845       # If we did not create any variables the trace we have is good enough.
# --> 846       return self._concrete_stateful_fn._filtered_call(canon_args, canon_kwds)  # pylint: disable=protected-access
#     847
#     848     def fn_with_cond(*inner_args, **inner_kwds):
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# InvalidArgumentError:  padded_shape[0]=32 is not divisible by block_shape[0]=6
# 	 [[node functional_3/conv2d_66/Conv2D/SpaceToBatchND (defined at \AppData\Local\Temp/ipykernel_5304/3542742736.py:8) ]] [Op:__inference_predict_function_13291]
#
# Function call stack:
# predict_function

# %%
#def resizeresult(input_size = (512,512,1)):
#    inputs = tf.keras.Input(shape=input_size)
#    conv10 = tf.keras.layers.experimental.preprocessing.Resizing(256,256,'area')(inputs)    
#    modelout = tf.keras.Model(inputs = inputs, outputs = conv10)
#    
#    return modelout
#import tensorflow.python.keras.backend as K
#model2 = resizeresult()
#model2 = model2(results)
#results = K.eval(model2)
#results.shape
##saveResult("data/membrane_hospital_aughand_fake/test/pred/",results)

# %%
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_fakeadd/test/labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((48,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# ['00.png', '01.png', '02.png', '03.png', '04.png', '05.png', '06.png', '07.png', '08.png', '09.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '30.png', '31.png', '32.png', '33.png', '34.png', '35.png', '36.png', '37.png', '38.png', '39.png', '40.png', '41.png', '42.png', '43.png', '44.png', '45.png', '46.png', '47.png']
# Precision= 0.7767594930724349 Recall= 0.7800144521786485 Sensitivity= 0.7800144521786485 Specificity= 0.9339205901613165 IoU= 0.6371750990005415 acc= 0.8988823890686035 DSC= 0.7783835698326007 F1= 0.7783835698326007

# %%
testGene = testGenerator("data/membrane_hospital_aughand_fakeadd/test/fake256")
results = model.predict_generator(testGene,48,verbose=1)
saveResult("data/membrane_hospital_aughand_fakeadd/test/pred/",results)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_fakeadd/test/fake256labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((48,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 48/48 [==============================] - 7s 142ms/step
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_fakeadd/test/pred/19_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ['00.png', '01.png', '02.png', '03.png', '04.png', '05.png', '06.png', '07.png', '08.png', '09.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '30.png', '31.png', '32.png', '33.png', '34.png', '35.png', '36.png', '37.png', '38.png', '39.png', '40.png', '41.png', '42.png', '43.png', '44.png', '45.png', '46.png', '47.png']
# Precision= 0.8760384222044003 Recall= 0.7133125206143206 Sensitivity= 0.7133125206143206 Specificity= 0.8980973597678623 IoU= 0.647914926243413 acc= 0.805264393488566 DSC= 0.7863451151818861 F1= 0.7863451151818861

# %%
testGene = testGenerator("data/membrane_hospital_aughand_fake/test/")
results = model.predict_generator(testGene,34,verbose=1)
#saveResult("data/membrane_hospital_aughand_inbreast/test/pred/",results)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_fake/test/labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((34,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 34/34 [==============================] - 5s 143ms/step
# ['00.png', '01.png', '02.png', '03.png', '04.png', '05.png', '06.png', '07.png', '08.png', '09.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '30.png', '31.png', '32.png', '33.png']
# Precision= 0.7869312336025516 Recall= 0.7265313896852744 Sensitivity= 0.7265313896852744 Specificity= 0.9423042014414337 IoU= 0.6071047938279435 acc= 0.8933707966524012 DSC= 0.7555260816339026 F1= 0.7555260816339026

# %%
testGene = testGenerator("data/membrane_hospital_aughand_cropcomadd/test/")
results = model.predict_generator(testGene,175,verbose=1)
#saveResult("data/membrane_hospital_aughand_inbreast/test/pred/",results)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_cropcomadd/test/labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((175,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 175/175 [==============================] - 25s 143ms/step
# ['000.png', '001.png', '002.png', '003.png', '004.png', '005.png', '006.png', '007.png', '008.png', '009.png', '010.png', '011.png', '012.png', '013.png', '014.png', '015.png', '016.png', '017.png', '018.png', '019.png', '020.png', '021.png', '022.png', '023.png', '024.png', '025.png', '026.png', '027.png', '028.png', '029.png', '030.png', '031.png', '032.png', '033.png', '034.png', '035.png', '036.png', '037.png', '038.png', '039.png', '040.png', '041.png', '042.png', '043.png', '044.png', '045.png', '046.png', '047.png', '048.png', '049.png', '050.png', '051.png', '052.png', '053.png', '054.png', '055.png', '056.png', '057.png', '058.png', '059.png', '060.png', '061.png', '062.png', '063.png', '064.png', '065.png', '066.png', '067.png', '068.png', '069.png', '070.png', '071.png', '072.png', '073.png', '074.png', '075.png', '076.png', '077.png', '078.png', '079.png', '080.png', '081.png', '082.png', '083.png', '084.png', '085.png', '086.png', '087.png', '088.png', '089.png', '090.png', '091.png', '092.png', '093.png', '094.png', '095.png', '096.png', '097.png', '098.png', '099.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png', '108.png', '109.png', '110.png', '111.png', '112.png', '113.png', '114.png', '115.png', '116.png', '117.png', '118.png', '119.png', '120.png', '121.png', '122.png', '123.png', '124.png', '125.png', '126.png', '127.png', '128.png', '129.png', '130.png', '131.png', '132.png', '133.png', '134.png', '135.png', '136.png', '137.png', '138.png', '139.png', '140.png', '141.png', '142.png', '143.png', '144.png', '145.png', '146.png', '147.png', '148.png', '149.png', '150.png', '151.png', '152.png', '153.png', '154.png', '155.png', '156.png', '157.png', '158.png', '159.png', '160.png', '161.png', '162.png', '163.png', '164.png', '165.png', '166.png', '167.png', '168.png', '169.png', '170.png', '171.png', '172.png', '173.png', '174.png']
# Precision= 0.7763613977729511 Recall= 0.7756913330550782 Sensitivity= 0.7756913330550782 Specificity= 0.9263638182116326 IoU= 0.6340219324470051 acc= 0.8890173775809151 DSC= 0.7760262207711436 F1= 0.7760262207711435

# %%
testGene = testGenerator("data/membrane_hospital_aughand_cropcomadd/test/fake256")
results = model.predict_generator(testGene,175,verbose=1)
#saveResult("data/membrane_hospital_aughand_inbreast/test/pred/",results)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_cropcomadd/test/fake256labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((175,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 175/175 [==============================] - 25s 145ms/step
# ['000.png', '001.png', '002.png', '003.png', '004.png', '005.png', '006.png', '007.png', '008.png', '009.png', '010.png', '011.png', '012.png', '013.png', '014.png', '015.png', '016.png', '017.png', '018.png', '019.png', '020.png', '021.png', '022.png', '023.png', '024.png', '025.png', '026.png', '027.png', '028.png', '029.png', '030.png', '031.png', '032.png', '033.png', '034.png', '035.png', '036.png', '037.png', '038.png', '039.png', '040.png', '041.png', '042.png', '043.png', '044.png', '045.png', '046.png', '047.png', '048.png', '049.png', '050.png', '051.png', '052.png', '053.png', '054.png', '055.png', '056.png', '057.png', '058.png', '059.png', '060.png', '061.png', '062.png', '063.png', '064.png', '065.png', '066.png', '067.png', '068.png', '069.png', '070.png', '071.png', '072.png', '073.png', '074.png', '075.png', '076.png', '077.png', '078.png', '079.png', '080.png', '081.png', '082.png', '083.png', '084.png', '085.png', '086.png', '087.png', '088.png', '089.png', '090.png', '091.png', '092.png', '093.png', '094.png', '095.png', '096.png', '097.png', '098.png', '099.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png', '108.png', '109.png', '110.png', '111.png', '112.png', '113.png', '114.png', '115.png', '116.png', '117.png', '118.png', '119.png', '120.png', '121.png', '122.png', '123.png', '124.png', '125.png', '126.png', '127.png', '128.png', '129.png', '130.png', '131.png', '132.png', '133.png', '134.png', '135.png', '136.png', '137.png', '138.png', '139.png', '140.png', '141.png', '142.png', '143.png', '144.png', '145.png', '146.png', '147.png', '148.png', '149.png', '150.png', '151.png', '152.png', '153.png', '154.png', '155.png', '156.png', '157.png', '158.png', '159.png', '160.png', '161.png', '162.png', '163.png', '164.png', '165.png', '166.png', '167.png', '168.png', '169.png', '170.png', '171.png', '172.png', '173.png', '174.png']
# Precision= 0.9260810615046756 Recall= 0.6572087254590091 Sensitivity= 0.6572087254590091 Specificity= 0.9343792948297426 IoU= 0.6244513822684722 acc= 0.7803450884137835 DSC= 0.7688151077768229 F1= 0.7688151077768228

# %%
testGene = testGenerator("data/membrane_hospital_aughand_cropcom/test/")
results = model.predict_generator(testGene,161,verbose=1)
#saveResult("data/membrane_hospital_aughand_inbreast/test/pred/",results)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_cropcom/test/labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((161,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 161/161 [==============================] - 23s 146ms/step
# ['000.png', '001.png', '002.png', '003.png', '004.png', '005.png', '006.png', '007.png', '008.png', '009.png', '010.png', '011.png', '012.png', '013.png', '014.png', '015.png', '016.png', '017.png', '018.png', '019.png', '020.png', '021.png', '022.png', '023.png', '024.png', '025.png', '026.png', '027.png', '028.png', '029.png', '030.png', '031.png', '032.png', '033.png', '034.png', '035.png', '036.png', '037.png', '038.png', '039.png', '040.png', '041.png', '042.png', '043.png', '044.png', '045.png', '046.png', '047.png', '048.png', '049.png', '050.png', '051.png', '052.png', '053.png', '054.png', '055.png', '056.png', '057.png', '058.png', '059.png', '060.png', '061.png', '062.png', '063.png', '064.png', '065.png', '066.png', '067.png', '068.png', '069.png', '070.png', '071.png', '072.png', '073.png', '074.png', '075.png', '076.png', '077.png', '078.png', '079.png', '080.png', '081.png', '082.png', '083.png', '084.png', '085.png', '086.png', '087.png', '088.png', '089.png', '090.png', '091.png', '092.png', '093.png', '094.png', '095.png', '096.png', '097.png', '098.png', '099.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png', '108.png', '109.png', '110.png', '111.png', '112.png', '113.png', '114.png', '115.png', '116.png', '117.png', '118.png', '119.png', '120.png', '121.png', '122.png', '123.png', '124.png', '125.png', '126.png', '127.png', '128.png', '129.png', '130.png', '131.png', '132.png', '133.png', '134.png', '135.png', '136.png', '137.png', '138.png', '139.png', '140.png', '141.png', '142.png', '143.png', '144.png', '145.png', '146.png', '147.png', '148.png', '149.png', '150.png', '151.png', '152.png', '153.png', '154.png', '155.png', '156.png', '157.png', '158.png', '159.png', '160.png']
# Precision= 0.7542206082547404 Recall= 0.7741478218570503 Sensitivity= 0.7741478218570503 Specificity= 0.9161613920926801 IoU= 0.6181940774617407 acc= 0.8807379918068833 DSC= 0.7640543072947402 F1= 0.7640543072947402

# %%
testGene = testGenerator("data/membrane_hospital_aughand_ddsm/test/fake256")
results = model.predict_generator(testGene,110,verbose=1)
#saveResult("data/membrane_hospital_aughand_inbreast/test/pred/",results)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_ddsm/test/fake256labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((110,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 110/110 [==============================] - 16s 143ms/step
# ['000.png', '001.png', '002.png', '003.png', '004.png', '005.png', '006.png', '007.png', '008.png', '009.png', '010.png', '011.png', '012.png', '013.png', '014.png', '015.png', '016.png', '017.png', '018.png', '019.png', '020.png', '021.png', '022.png', '023.png', '024.png', '025.png', '026.png', '027.png', '028.png', '029.png', '030.png', '031.png', '032.png', '033.png', '034.png', '035.png', '036.png', '037.png', '038.png', '039.png', '040.png', '041.png', '042.png', '043.png', '044.png', '045.png', '046.png', '047.png', '048.png', '049.png', '050.png', '051.png', '052.png', '053.png', '054.png', '055.png', '056.png', '057.png', '058.png', '059.png', '060.png', '061.png', '062.png', '063.png', '064.png', '065.png', '066.png', '067.png', '068.png', '069.png', '070.png', '071.png', '072.png', '073.png', '074.png', '075.png', '076.png', '077.png', '078.png', '079.png', '080.png', '081.png', '082.png', '083.png', '084.png', '085.png', '086.png', '087.png', '088.png', '089.png', '090.png', '091.png', '092.png', '093.png', '094.png', '095.png', '096.png', '097.png', '098.png', '099.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png', '108.png', '109.png']
# Precision= 0.957472297148448 Recall= 0.6248217935830591 Sensitivity= 0.6248217935830591 Specificity= 0.9592498962317021 IoU= 0.6079496792244551 acc= 0.7603088032115589 DSC= 0.7561799813507607 F1= 0.7561799813507607

# %%
testGene = testGenerator("data/membrane_hospital_aughand_ddsm/test/")
results = model.predict_generator(testGene,110,verbose=1)
#saveResult("data/membrane_hospital_aughand_inbreast/test/pred/",results)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_ddsm/test/labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((110,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 110/110 [==============================] - 16s 144ms/step
# ['000.png', '001.png', '002.png', '003.png', '004.png', '005.png', '006.png', '007.png', '008.png', '009.png', '010.png', '011.png', '012.png', '013.png', '014.png', '015.png', '016.png', '017.png', '018.png', '019.png', '020.png', '021.png', '022.png', '023.png', '024.png', '025.png', '026.png', '027.png', '028.png', '029.png', '030.png', '031.png', '032.png', '033.png', '034.png', '035.png', '036.png', '037.png', '038.png', '039.png', '040.png', '041.png', '042.png', '043.png', '044.png', '045.png', '046.png', '047.png', '048.png', '049.png', '050.png', '051.png', '052.png', '053.png', '054.png', '055.png', '056.png', '057.png', '058.png', '059.png', '060.png', '061.png', '062.png', '063.png', '064.png', '065.png', '066.png', '067.png', '068.png', '069.png', '070.png', '071.png', '072.png', '073.png', '074.png', '075.png', '076.png', '077.png', '078.png', '079.png', '080.png', '081.png', '082.png', '083.png', '084.png', '085.png', '086.png', '087.png', '088.png', '089.png', '090.png', '091.png', '092.png', '093.png', '094.png', '095.png', '096.png', '097.png', '098.png', '099.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png', '108.png', '109.png']
# Precision= 0.7620428980946194 Recall= 0.7742796933425022 Sensitivity= 0.7742796933425022 Specificity= 0.9158433222380133 IoU= 0.6235249581286636 acc= 0.879291465065696 DSC= 0.7681125627380094 F1= 0.7681125627380094

# %%
testGene = testGenerator("data/membrane_hospital_aughand_inbreast/test/fake256")
results = model.predict_generator(testGene,17,verbose=1)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_inbreast/test/fake256labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((17,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 17/17 [==============================] - 2s 138ms/step
# ['00.png', '01.png', '02.png', '03.png', '04.png', '05.png', '06.png', '07.png', '08.png', '09.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png']
# Precision= 0.8881660420077604 Recall= 0.8215342278608357 Sensitivity= 0.8215342278608357 Specificity= 0.9123796710989315 IoU= 0.7445182970281048 acc= 0.8707187876981848 DSC= 0.853551720605554 F1= 0.8535517206055538

# %%
testGene = testGenerator("data/membrane_hospital_aughand_inbreast/test/")
results = model.predict_generator(testGene,17,verbose=1)
from sklearn.metrics import PrecisionRecallDisplay
# predicted_list ='data/membrane_hospital/test/pred_resize'
# groundtruth_list='data/membrane_hospital/test/labelpng'
gt_path='data/membrane_hospital_aughand_inbreast/test/labelpng'


files=sorted(os.listdir(gt_path))
print(files)
intputshape = 512
gth1 = np.zeros((17,intputshape,intputshape)).astype(int) 
for i,item in enumerate(results):
    gth = io.imread(os.path.join(gt_path,files[i]))
    gth = trans.resize(gth,(intputshape,intputshape))#512,512
    gth= np.array(((gth - np.min(gth))/np.ptp(gth))>0.1).astype(float)
    gth1[i,:,:] = gth

display = PrecisionRecallDisplay.from_predictions(gth1.flatten(),results[:,:,:,0].flatten(), name="LinearSVC")
_ = display.ax_.set_title("Precision-Recall curve")

Threshold = 0.5
results = np.where(results > Threshold, 1, 0)

TP = np.count_nonzero(results[:,:,:,0].flatten() * gth1.flatten())
TN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * (gth1.flatten() - 1))
FP = np.count_nonzero(results[:,:,:,0].flatten() * (gth1.flatten() - 1))
FN = np.count_nonzero((results[:,:,:,0].flatten() - 1) * gth1.flatten())    
precision = TP / (TP + FP)
recall = TP / (TP + FN)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)
DSC = 2* TP / (FP + 2 * TP+ FN)
f1 = 2 * precision * recall / (precision + recall)
accuracy = (TP + TN) / (TP + FP + TN + FN)
IoU=TP/(TP+FP+FN)
print("Precision=",precision, "Recall=",recall,"Sensitivity=" ,Sensitivity,"Specificity=",Specificity,"IoU=",IoU, "acc=",accuracy,"DSC=",DSC, "F1=",f1)
# Out:
# 17/17 [==============================] - 2s 137ms/step
# ['00.png', '01.png', '02.png', '03.png', '04.png', '05.png', '06.png', '07.png', '08.png', '09.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png']
# Precision= 0.8835393572838222 Recall= 0.8290540571665477 Sensitivity= 0.8290540571665477 Specificity= 0.9648136485571294 IoU= 0.7473811064259547 acc= 0.9317476609173942 DSC= 0.8554299959836781 F1= 0.8554299959836781

# %%
gt_path='data/membrane_hospital_aughand_ddsm/test/labelpng'
evalResult(gt_path,results,target_size=(512,512))
# Out:
# num:  0 Prec= 0.24466192170818504 sensitivity= 0.5468909945142917 Recall= 1.0 IOU= 0.24466192170818504 acc= 0.6048812866210938 F1= 0.39313795568263044
# num:  1 Prec= 0.44450313903167477 sensitivity= 0.5826013943310773 Recall= 1.0 IOU= 0.44450313903167477 acc= 0.6871070861816406 F1= 0.6154408765489402
# num:  2 Prec= 0.9300466355762825 sensitivity= 0.973713706993178 Recall= 0.7110329100443353 IOU= 0.674937092751107 acc= 0.8871498107910156 F1= 0.8059253039079978
# num:  3 Prec= 0.8749695157170545 sensitivity= 0.9212772147602192 Recall= 0.4925220004913082 IOU= 0.46013756606613704 acc= 0.6949043273925781 F1= 0.6302660471996856
# num:  4 Prec= 0.6358475585549821 sensitivity= 0.9574757083518766 Recall= 0.34495606478290836 IOU= 0.2880496358241165 acc= 0.8489837646484375 F1= 0.44726480690290693
# num:  5 Prec= 0.8396812888538657 sensitivity= 0.980430089138753 Recall= 0.2556651559584111 IOU= 0.2437660456012811 acc= 0.7730178833007812 F1= 0.39198054403139115
# num:  6 Prec= 0 sensitivity= 1.0 Recall= 0.0 IOU= 0.0 acc= 0.8723335266113281 F1= 0.0
# C:\Users\414\AppData\Local\Temp/ipykernel_3188/3600196795.py:109: RuntimeWarning: invalid value encountered in true_divide
#   img1=np.array(((img - np.min(img))/np.ptp(img))>0.1).astype(float)
# C:\Users\414\AppData\Local\Temp/ipykernel_3188/3600196795.py:53: RuntimeWarning: invalid value encountered in double_scalars
#   prec=tp/(tp+fp)
# num:  7 Prec= 0.28897946859903384 sensitivity= 0.8052473794115823 Recall= 0.9425377911270865 IOU= 0.28397644161585595 acc= 0.8158836364746094 F1= 0.44233902182578655
# num:  8 Prec= 0.9676228529239321 sensitivity= 0.9885354432423704 Recall= 0.3373431952214761 IOU= 0.33357787725891214 acc= 0.6604080200195312 F1= 0.5002750614678179
# num:  9 Prec= 0.9888002019118528 sensitivity= 0.993619124651748 Recall= 0.4154725134880761 IOU= 0.41352649356132576 acc= 0.6608734130859375 F1= 0.5850990348535479
# num:  10 Prec= 0.2851330168018245 sensitivity= 0.40346337109638786 Recall= 1.0 IOU= 0.2851330168018245 acc= 0.5181198120117188 F1= 0.4437408627340461
# num:  11 Prec= 0.47597295911426446 sensitivity= 0.41492723905664897 Recall= 1.0 IOU= 0.47597295911426446 acc= 0.6179542541503906 F1= 0.6449616250420972
# num:  12 Prec= 1.0 sensitivity= 1.0 Recall= 0.28040656133641945 IOU= 0.28040656133641945 acc= 0.7272262573242188 F1= 0.4379961331090746
# num:  13 Prec= 0.0 sensitivity= 0.9723765690035426 Recall= 0.0 IOU= 0.0 acc= 0.9098930358886719 F1= 0.0
# num:  14 Prec= 1.0 sensitivity= 1.0 Recall= 0.057364662998465814 IOU= 0.057364662998465814 acc= 0.6882705688476562 F1= 0.10850497469017281
# num:  15 Prec= 0.39609588544060376 sensitivity= 0.897115305365532 Recall= 0.8404331759392322 IOU= 0.3683914510686164 acc= 0.8929023742675781 F1= 0.5384299219071106
# num:  16 Prec= 0.5452402735350215 sensitivity= 0.867367659362775 Recall= 0.8570035828316557 IOU= 0.4997725851384388 acc= 0.8657455444335938 F1= 0.6664644894709907
#  Precision= 0.5833855716334457 sensitivity=  0.8414730117223519 Recall= 0.5608669184834926 IoU= 0.3149516146986249 acc= 0.748567917767693 F1= 0.4501074505514233

# %%
testGene = testGenerator("data/membrane_hospital_aughand_123/test/")
model = unet()
model.load_weights("test_hope2.hdf5")
results = model.predict_generator(testGene,221,verbose=1)
saveResult("data/membrane_hospital_aughand_123/test/pred/",results)
gt_path='data/membrane_hospital_aughand_123/test/labelpng'
evalResult(gt_path,results,target_size=(512,512),threshold=0.5)
#evalResult(gt_path,results)
# Out:
# 221/221 [==============================] - 227s 1s/step
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/0_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/2_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/4_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/6_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/7_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/10_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/13_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/16_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/19_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/20_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/21_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/24_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/30_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/31_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/32_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/33_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/34_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/35_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/37_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/38_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/39_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/40_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/41_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/42_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/43_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/44_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/45_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/46_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/47_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/48_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/49_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/50_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/51_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/52_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/53_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/54_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/55_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/56_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/57_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/58_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/59_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/60_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/61_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/62_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/63_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/64_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/65_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/66_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/67_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/68_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/69_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/70_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/71_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/72_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/73_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/74_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/75_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/76_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/77_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/78_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/79_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/80_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/81_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/82_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/83_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/84_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/85_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/87_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/88_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/89_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/90_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/92_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/93_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/94_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/95_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/96_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/97_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/98_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/99_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/100_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/101_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/102_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/103_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/104_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/105_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/106_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/107_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/108_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/109_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/110_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/111_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/112_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/114_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/115_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/116_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/117_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/118_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/119_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/120_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/121_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/122_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/123_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/124_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/125_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/126_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/127_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/128_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/129_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/130_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/131_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/132_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/133_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/135_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/136_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/137_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/138_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/139_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/141_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/142_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/143_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/144_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/145_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/146_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/147_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/148_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/149_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/151_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/152_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/153_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/154_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/155_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/156_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/157_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/158_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/159_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/160_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/161_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/162_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/163_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/164_predict.png is a low contrast image
# ...
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/179_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/180_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/181_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/182_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/183_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/184_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/185_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/186_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/188_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/189_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/190_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/191_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/192_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/193_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/194_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/195_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/196_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/197_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/198_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/199_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/200_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/201_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/203_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/204_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/205_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/206_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/207_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/208_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/209_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/210_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/211_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/212_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/213_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/214_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/215_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/216_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/217_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/218_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/219_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# C:\Users\414\Desktop\unet-master\data.py:209: UserWarning: data/membrane_hospital_aughand_123/test/pred/220_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ['0.png', '1.png', '10.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png', '108.png', '109.png', '11.png', '110.png', '111.png', '112.png', '113.png', '114.png', '115.png', '116.png', '117.png', '118.png', '119.png', '12.png', '120.png', '121.png', '122.png', '123.png', '124.png', '125.png', '126.png', '127.png', '128.png', '129.png', '13.png', '130.png', '131.png', '132.png', '133.png', '134.png', '135.png', '136.png', '137.png', '138.png', '139.png', '14.png', '140.png', '141.png', '142.png', '143.png', '144.png', '145.png', '146.png', '147.png', '148.png', '149.png', '15.png', '150.png', '151.png', '152.png', '153.png', '154.png', '155.png', '156.png', '157.png', '158.png', '159.png', '16.png', '160.png', '161.png', '162.png', '163.png', '164.png', '165.png', '166.png', '167.png', '168.png', '169.png', '17.png', '170.png', '171.png', '172.png', '173.png', '174.png', '175.png', '176.png', '177.png', '178.png', '179.png', '18.png', '180.png', '181.png', '182.png', '183.png', '184.png', '185.png', '186.png', '187.png', '188.png', '189.png', '19.png', '190.png', '191.png', '192.png', '193.png', '194.png', '195.png', '196.png', '197.png', '198.png', '199.png', '2.png', '20.png', '200.png', '201.png', '202.png', '203.png', '204.png', '205.png', '206.png', '207.png', '208.png', '209.png', '21.png', '210.png', '211.png', '212.png', '213.png', '214.png', '215.png', '216.png', '217.png', '218.png', '219.png', '22.png', '220.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '30.png', '31.png', '32.png', '33.png', '34.png', '35.png', '36.png', '37.png', '38.png', '39.png', '4.png', '40.png', '41.png', '42.png', '43.png', '44.png', '45.png', '46.png', '47.png', '48.png', '49.png', '5.png', '50.png', '51.png', '52.png', '53.png', '54.png', '55.png', '56.png', '57.png', '58.png', '59.png', '6.png', '60.png', '61.png', '62.png', '63.png', '64.png', '65.png', '66.png', '67.png', '68.png', '69.png', '7.png', '70.png', '71.png', '72.png', '73.png', '74.png', '75.png', '76.png', '77.png', '78.png', '79.png', '8.png', '80.png', '81.png', '82.png', '83.png', '84.png', '85.png', '86.png', '87.png', '88.png', '89.png', '9.png', '90.png', '91.png', '92.png', '93.png', '94.png', '95.png', '96.png', '97.png', '98.png', '99.png']
# Precision= 0.01847120075437778 Recall= 0.0045448810827578515 IoU= 0.0035807398528417997 acc= 0.980990828432109 F1= 0.0058997244980436335
# (0.01847120075437778, 0.0045448810827578515)

# %% [markdown]
# ### 資料可視化

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './testjpg/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
for file_name in filename_list:
    original = Image.open('./testjpg/'+file_name)
    img_name_temp = file_name.split(".jpg")
    img_name_temp = img_name_temp[0] + '.png'
    original = original.convert("L")
    original.save('testpng1/'+img_name_temp)

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand_fake/test/pred/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:
    img_name_temp = file_name.split("_predict")
    orignal = Image.open('./data/membrane_hospital_aughand_fake/test/'+img_name_temp[0]+'.png')
    w = orignal.width
    h = orignal.height
    mask = Image.open('./data/membrane_hospital_aughand_fake/test/pred/'+file_name)
    mask_new = mask.resize((w,h))
    mask_new.save('./data/membrane_hospital_aughand_fake/test/pred_resize/'+img_name_temp[0]+'_predictmask_resize.png')
# Out:
# path： ./data/membrane_hospital_aughand_fake/test/pred/
# directory： []
# file1： ['0_predict.png', '10_predict.png', '11_predict.png', '12_predict.png', '13_predict.png', '14_predict.png', '15_predict.png', '16_predict.png', '17_predict.png', '18_predict.png', '19_predict.png', '1_predict.png', '20_predict.png', '21_predict.png', '22_predict.png', '23_predict.png', '24_predict.png', '25_predict.png', '26_predict.png', '27_predict.png', '28_predict.png', '29_predict.png', '2_predict.png', '3_predict.png', '4_predict.png', '5_predict.png', '6_predict.png', '7_predict.png', '8_predict.png', '9_predict.png']

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand_fake/test/pred_resize/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:
    img_name_temp = file_name.split("_predict")
    original = Image.open('./data/membrane_hospital_aughand_fake/test/pred_resize/'+file_name)
    original = original.convert("RGBA")
    w = original.width
    h = original.height
    for i in range(0,w):
        for j in range(0,h):
            data = (original.getpixel((i,j)))#540,1215
            #print (data)
            if (data[0]>=128 and data[1]>=128 and data[2]>=128):
                original.putpixel((i,j),(0,128,255,100))
            else :
                original.putpixel((i,j),(255,255,255,0))
    original.save('./data/membrane_hospital_aughand_fake/test/temp/'+img_name_temp[0]+'_rgbapredictmask_resize.png')
    print('success'+img_name_temp[0])
# Out:
# path： ./data/membrane_hospital_aughand_fake/test/pred_resize/
# directory： []
# file1： ['0_predictmask_resize.png', '10_predictmask_resize.png', '11_predictmask_resize.png', '12_predictmask_resize.png', '13_predictmask_resize.png', '14_predictmask_resize.png', '15_predictmask_resize.png', '16_predictmask_resize.png', '17_predictmask_resize.png', '18_predictmask_resize.png', '19_predictmask_resize.png', '1_predictmask_resize.png', '20_predictmask_resize.png', '21_predictmask_resize.png', '22_predictmask_resize.png', '23_predictmask_resize.png', '24_predictmask_resize.png', '25_predictmask_resize.png', '26_predictmask_resize.png', '27_predictmask_resize.png', '28_predictmask_resize.png', '29_predictmask_resize.png', '2_predictmask_resize.png', '3_predictmask_resize.png', '4_predictmask_resize.png', '5_predictmask_resize.png', '6_predictmask_resize.png', '7_predictmask_resize.png', '8_predictmask_resize.png', '9_predictmask_resize.png']
# success0
# success10
# success11
# success12
# success13
# success14
# success15
# success16
# success17
# success18
# success19
# success1
# success20
# success21
# success22
# success23
# success24
# success25
# success26
# success27
# success28
# success29
# success2
# success3
# success4
# success5
# success6
# success7
# success8
# success9

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand_fake/test/pred_resize/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:    
    img_name_temp = file_name.split("_predict")
    imagea = Image.open('./data/membrane_hospital_aughand_fake/test/'+img_name_temp[0]+'.png')
    imageb = Image.open('./data/membrane_hospital_aughand_fake/test/temp/'+img_name_temp[0]+'_rgbapredictmask_resize.png')
    imagec = Image.open('./data/membrane_hospital_aughand_fake/test/labeltemp/'+img_name_temp[0]+'_rgba_gt.png')
    newimageb = imageb
    imagea = imagea.convert("RGBA")
    #resultimage = Image.new('RGBA',imagea.size,(0,0,0,0))
    resultimage = imagea
    #resultimage.paste(imagea,(0,0))
    resultimage.paste(newimageb,(0,0),newimageb)
    resultimage.paste(imagec,(0,0),imagec)
    resultimage.save('./data/membrane_hospital_aughand_fake/test/visualresult/'+img_name_temp[0]+'_combinepredictmask.png')
# Out:
# path： ./data/membrane_hospital_aughand_fake/test/pred_resize/
# directory： []
# file1： ['0_predictmask_resize.png', '10_predictmask_resize.png', '11_predictmask_resize.png', '12_predictmask_resize.png', '13_predictmask_resize.png', '14_predictmask_resize.png', '15_predictmask_resize.png', '16_predictmask_resize.png', '17_predictmask_resize.png', '18_predictmask_resize.png', '19_predictmask_resize.png', '1_predictmask_resize.png', '20_predictmask_resize.png', '21_predictmask_resize.png', '22_predictmask_resize.png', '23_predictmask_resize.png', '24_predictmask_resize.png', '25_predictmask_resize.png', '26_predictmask_resize.png', '27_predictmask_resize.png', '28_predictmask_resize.png', '29_predictmask_resize.png', '2_predictmask_resize.png', '3_predictmask_resize.png', '4_predictmask_resize.png', '5_predictmask_resize.png', '6_predictmask_resize.png', '7_predictmask_resize.png', '8_predictmask_resize.png', '9_predictmask_resize.png']

# %% [markdown]
# ## 轉groundtruth

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand_fake/test/labelpng/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    

for file_name in filename_list:
    img_name_temp = file_name.split(".png")
    original = Image.open('./data/membrane_hospital_aughand_fake/test/labelpng/'+file_name)
    print(file_name)
    original = original.convert("RGBA")
    w = original.width
    h = original.height
    for i in range(0,w):
        for j in range(0,h):
            data = (original.getpixel((i,j)))#540,1215
            #print (data)
            if (data[0]==255 and data[1]==255 and data[2]==255):
                original.putpixel((i,j),(255,0,0,100))
            else :
                original.putpixel((i,j),(255,255,255,0))
    original.save('./data/membrane_hospital_aughand_fake/test/labeltemp/'+img_name_temp[0]+'_rgba_gt.png')
    print('success'+img_name_temp[0])
# Out:
# path： ./data/membrane_hospital_aughand_fake/test/labelpng/
# directory： []
# file1： ['00.png', '01.png', '02.png', '03.png', '04.png', '05.png', '06.png', '07.png', '08.png', '09.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png']
# 00.png
# success00
# 01.png
# success01
# 02.png
# success02
# 03.png
# success03
# 04.png
# success04
# 05.png
# success05
# 06.png
# success06
# 07.png
# success07
# 08.png
# success08
# 09.png
# success09
# 10.png
# success10
# 11.png
# success11
# 12.png
# success12
# 13.png
# success13
# 14.png
# success14
# 15.png
# success15
# 16.png
# success16
# 17.png
# success17
# 18.png
# success18
# 19.png
# success19
# 20.png
# success20
# 21.png
# success21
# 22.png
# success22
# 23.png
# success23
# 24.png
# success24
# 25.png
# success25
# 26.png
# success26
# 27.png
# success27
# 28.png
# success28
# 29.png
# success29

# %%
import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand_fake/test/label/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
for file_name in filename_list:
    img_name_temp = file_name.split(".jpg")
    original = Image.open('./data/membrane_hospital_aughand_fake/test/label/'+file_name)
    print(file_name)
    original = original.convert("L")
    original.save('./data/membrane_hospital_aughand_fake/test/labelpng/'+img_name_temp[0]+'.png')
    print('success'+img_name_temp[0])

# %% [markdown]
# # 資料增強(垂直翻轉+90度旋轉)

# %% [markdown]
# ## 單張處理

# %%
#from PIL import Image
#
#img = Image.open("C:/Users/414/Desktop/unet-master/data/membrane_hospital/train/image/1.jpg")
#mask = Image.open("C:/Users/414/Desktop/unet-master/data/membrane_hospital/train/label/1.jpg")
##img.show()
#newnew_img=img.transpose(Image.ROTATE_180) 
#newnew_mask=mask.transpose(Image.ROTATE_180) 
#new_img = img.transpose(Image.FLIP_LEFT_RIGHT) 
#new_mask = mask.transpose(Image.FLIP_LEFT_RIGHT) 
##new_img.show()
#new_img.save("C:/Users/414/Desktop/unet-master/data/membrane_hospital/aughand/1-rotate.jpg")
#newnew_img.save("C:/Users/414/Desktop/unet-master/data/membrane_hospital/aughand/1-rotate_1.jpg")
#new_mask.save("C:/Users/414/Desktop/unet-master/data/membrane_hospital/aughand/1_mask-rotate.jpg")
#newnew_mask.save("C:/Users/414/Desktop/unet-master/data/membrane_hospital/aughand/1_mask-rotate_1.jpg")

# %% [markdown]
# ## 批量處理

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital/train/image/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
filename_list    
for file_name in filename_list:
    img_name_temp = file_name.split(".jpg")
    original_img = Image.open('./data/membrane_hospital/train/image/'+file_name)
    original_mask = Image.open('./data/membrane_hospital/train/label/'+img_name_temp[0]+".jpg")
    #print(file_name)
    new_img_90=original_img.transpose(Image.ROTATE_90) 
    new_mask_90 = original_mask.transpose(Image.ROTATE_90) 
    new_img_180=original_img.transpose(Image.ROTATE_180) 
    new_mask_180 = original_mask.transpose(Image.ROTATE_180) 
    new_img_270=original_img.transpose(Image.ROTATE_270) 
    new_mask_270 = original_mask.transpose(Image.ROTATE_270) 
    original_img.save('./data/membrane_hospital/train/aughand/image_beforeflip/'+img_name_temp[0]+'.jpg')
    original_mask.save('./data/membrane_hospital/train/aughand/label_beforeflip/'+img_name_temp[0]+'.jpg')
    
    new_img_90.save('./data/membrane_hospital/train/aughand/image_beforeflip/'+img_name_temp[0]+'_rotate_90.jpg')
    new_mask_90.save('./data/membrane_hospital/train/aughand/label_beforeflip/'+img_name_temp[0]+'_rotate_90.jpg')
    new_img_180.save('./data/membrane_hospital/train/aughand/image_beforeflip/'+img_name_temp[0]+'_rotate_180.jpg')
    new_mask_180.save('./data/membrane_hospital/train/aughand/label_beforeflip/'+img_name_temp[0]+'_rotate_180.jpg')
    new_img_270.save('./data/membrane_hospital/train/aughand/image_beforeflip/'+img_name_temp[0]+'_rotate_270.jpg')
    new_mask_270.save('./data/membrane_hospital/train/aughand/label_beforeflip/'+img_name_temp[0]+'_rotate_270.jpg')
    print('success'+img_name_temp[0])

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital/train/aughand/image_beforeflip/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:
    img_name_temp = file_name.split(".jpg")
    original_img = Image.open('./data/membrane_hospital/train/aughand/image_beforeflip/'+file_name)
    original_mask = Image.open('./data/membrane_hospital/train/aughand/label_beforeflip/'+file_name)
    #print(file_name)
    new_img=original_img.transpose(Image.FLIP_LEFT_RIGHT) 
    new_mask= original_mask.transpose(Image.FLIP_LEFT_RIGHT) 
    
    original_img.save('./data/membrane_hospital/train/aughand/image/'+img_name_temp[0]+'.jpg')
    original_mask.save('./data/membrane_hospital/train/aughand/label/'+img_name_temp[0]+'.jpg')
    new_img.save('./data/membrane_hospital/train/aughand/image/'+img_name_temp[0]+'_flip.jpg')
    new_mask.save('./data/membrane_hospital/train/aughand/label/'+img_name_temp[0]+'_flip.jpg')
    print('success'+img_name_temp[0])

# %%
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital/train/aughand/image/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files

i=0

for file_name in filename_list:
    img_name_temp = str(i)+".jpg"
    file_oldname_image = os.path.join("./data/membrane_hospital/train/aughand/image/", file_name)
    file_newname_image = os.path.join("./data/membrane_hospital/train/aughand/image/", img_name_temp)
    
    os.rename(file_oldname_image, file_newname_image)
    file_oldname_mask = os.path.join("./data/membrane_hospital/train/aughand/label/", file_name)
    file_newname_mask = os.path.join("./data/membrane_hospital/train/aughand/label/", img_name_temp)
    os.rename(file_oldname_mask, file_newname_mask)
    i=i+1

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital/val/image/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
filename_list    
for file_name in filename_list:
    img_name_temp = file_name.split(".jpg")
    original_img = Image.open('./data/membrane_hospital/val/image/'+file_name)
    original_mask = Image.open('./data/membrane_hospital/val/label/'+img_name_temp[0]+".jpg")
    #print(file_name)
    new_img_90=original_img.transpose(Image.ROTATE_90) 
    new_mask_90 = original_mask.transpose(Image.ROTATE_90) 
    new_img_180=original_img.transpose(Image.ROTATE_180) 
    new_mask_180 = original_mask.transpose(Image.ROTATE_180) 
    new_img_270=original_img.transpose(Image.ROTATE_270) 
    new_mask_270 = original_mask.transpose(Image.ROTATE_270) 
    original_img.save('./data/membrane_hospital/val/aughand/image_beforeflip/'+img_name_temp[0]+'.jpg')
    original_mask.save('./data/membrane_hospital/val/aughand/label_beforeflip/'+img_name_temp[0]+'.jpg')
    
    new_img_90.save('./data/membrane_hospital/val/aughand/image_beforeflip/'+img_name_temp[0]+'_rotate_90.jpg')
    new_mask_90.save('./data/membrane_hospital/val/aughand/label_beforeflip/'+img_name_temp[0]+'_rotate_90.jpg')
    new_img_180.save('./data/membrane_hospital/val/aughand/image_beforeflip/'+img_name_temp[0]+'_rotate_180.jpg')
    new_mask_180.save('./data/membrane_hospital/val/aughand/label_beforeflip/'+img_name_temp[0]+'_rotate_180.jpg')
    new_img_270.save('./data/membrane_hospital/val/aughand/image_beforeflip/'+img_name_temp[0]+'_rotate_270.jpg')
    new_mask_270.save('./data/membrane_hospital/val/aughand/label_beforeflip/'+img_name_temp[0]+'_rotate_270.jpg')
    print('success'+img_name_temp[0])

# %%
# import os
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital/val/aughand/image_beforeflip/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:
    img_name_temp = file_name.split(".jpg")
    original_img = Image.open('./data/membrane_hospital/val/aughand/image_beforeflip/'+file_name)
    original_mask = Image.open('./data/membrane_hospital/val/aughand/label_beforeflip/'+file_name)
    #print(file_name)
    new_img=original_img.transpose(Image.FLIP_LEFT_RIGHT) 
    new_mask= original_mask.transpose(Image.FLIP_LEFT_RIGHT) 
    original_img.save('./data/membrane_hospital/val/aughand/image/'+img_name_temp[0]+'.jpg')
    original_mask.save('./data/membrane_hospital/val/aughand/label/'+img_name_temp[0]+'.jpg')
    new_img.save('./data/membrane_hospital/val/aughand/image/'+img_name_temp[0]+'_flip.jpg')
    new_mask.save('./data/membrane_hospital/val/aughand/label/'+img_name_temp[0]+'_flip.jpg')
    print('success'+img_name_temp[0])

# %%
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital/val/aughand/image/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files

i=1000

for file_name in filename_list:
    img_name_temp = str(i)+".jpg"
    file_oldname_image = os.path.join("./data/membrane_hospital/val/aughand/image/", file_name)
    file_newname_image = os.path.join("./data/membrane_hospital/val/aughand/image/", img_name_temp)
    
    os.rename(file_oldname_image, file_newname_image)
    file_oldname_mask = os.path.join("./data/membrane_hospital/val/aughand/label/", file_name)
    file_newname_mask = os.path.join("./data/membrane_hospital/val/aughand/label/", img_name_temp)
    os.rename(file_oldname_mask, file_newname_mask)
    i=i+1

# %% [markdown]
# 轉uint8

# %%
from PIL import Image, ImageDraw, ImageChops
yourPath = './data/membrane_hospital_aughand/train/aug_resize/'
allList = os.walk(yourPath)
for root, dirs, files in allList:
    print("path：", root)#   列出目前讀取到的路徑
    print("directory：", dirs)#   列出在這個路徑下讀取到的資料夾(第一層讀完才會讀第二層)    
    print("file1：", files)#   列出在這個路徑下讀取到的所有檔案
    filename_list = []
    filename_list = files
    
for file_name in filename_list:
    image = Image.open("./data/membrane_hospital_aughand/train/aug_resize/"+file_name)
    image_1 = image.convert('L')
    image_1.save("./data/membrane_hospital_aughand/train/aug_resize_8L/"+file_name)

# %%
import numpy as np
from shapely.geometry import Polygon,Point
import matplotlib.pyplot as plt
import shapely
import cv2 as cv
import os
import gc


def evaluation(ground,pred,iou_value):
    
    # ground= array of ground-truth contours.
    # preds = array of predicted contours.
    # iou_value= iou treshold for TP and otherwise.
    
        truth=np.squeeze(ground)
        preds=np.squeeze(pred)
      #we will use this function to check iou less than threshold
        def CheckLess(list1,val):
            return(all(x<=val for x in list1))
    
      # Using predicted output as the reference
        prob1=[]
        for i in range(len(preds)):
            f1=preds[i]
            # define a Shapely polygone for prediction i
            f1=shapely.geometry.Polygon(f1)
            # determine the radius
            f1_radius=np.sqrt((f1.area)/np.pi)
            #buffer the polygon fromt the centroid
            f1_buffered=shapely.geometry.Point(f1.centroid).buffer(f1_radius*500)
            cont=[]
            for i in range(len(truth)):
            ff=shapely.geometry.Polygon(np.squeeze(truth[i]))
            if f1_buffered.contains(ff)== True:
                iou=(ff.intersection(f1).area)/(ff.union(f1).area)  
            
                cont.append((iou))
    
            prob1.append(cont)
    
        fp=0
    
        for t in prob1:
            if CheckLess(t,iou_value)==True:
                fp=fp+1
        
        prob2=[]
      #loop through each groun truth instance 
        for i in range(len(truth)):
            f1=truth[i]
            f1=shapely.geometry.Polygon(f1)
            #find radius
            f1_radius=np.sqrt((f1.area)/np.pi)
            #buffer the polygon from the centroid
            f1_buffered=shapely.geometry.Point(f1.centroid).buffer(f1_radius*500)
            cont=[]
            # merge up the ground truth instance against prediction
            # to determine the IoU
            for i in range(len(preds)):
                ff=shapely.geometry.Polygon(np.squeeze(preds[i]))
                if f1_buffered.contains(ff)== True:
                #calculate IoU
                iou=(ff.intersection(f1).area)/(ff.union(f1).area)
                cont.append((iou))
          # probability of a given prediction to be contained in a
          # ground truth instance
            prob2.append(cont)
        fn=0
        tp=0
        for t in prob2:
            if np.sum(t)==0:
                fn=fn+1
            elif CheckLess(t,iou_value)==False:
                tp=tp+1
      
      #lets add this section just to print the results
        print("TP:",tp,"\t FP:",fp,"\t FN:",fn,"\t GT:",truth.shape[0])
        precision=round(tp/(tp+fp),3) 
        recall=round(tp/(tp+fn),3)
        f1= round(2*((precision*recall)/(precision+recall)),3)
        print("Precall:",precision,"\t Recall:",recall, "\t F1 score:",f1)
  
    return tp,fp,fn,precision,recall,f1

# %%
import numpy as np
from shapely.geometry import Polygon,Point
import matplotlib.pyplot as plt
import shapely
import cv2 as cv
import os
import gc

# %%
def evaluation(ground,pred,iou_value):
    truth=np.squeeze(ground)
    print("pass")
    preds=np.squeeze(pred)
    print("pass")
    def CheckLess(list1,val):
        return(all(x<=val for x in list1))
    prob1=[]
    for i in range(len(preds)):
        f1=preds[i]
        # define a Shapely polygone for prediction i
        f1=shapely.geometry.Polygon(f1)
        # determine the radius
        f1_radius=np.sqrt((f1.area)/np.pi)
        #buffer the polygon fromt the centroid
        f1_buffered=shapely.geometry.Point(f1.centroid).buffer(f1_radius*500)
        cont=[]
        for i in range(len(truth)):
            ff=shapely.geometry.Polygon(np.squeeze(truth[i]))
            if f1_buffered.contains(ff)== True:
                iou=(ff.intersection(f1).area)/(ff.union(f1).area)          
                cont.append((iou))

        prob1.append(cont)
    
    fp=0
    for t in prob1:
        if CheckLess(t,iou_value)==True:
            fp=fp+1
        
    prob2=[]
    
    for i in range(len(truth)):
        f1=truth[i]
        f1=shapely.geometry.Polygon(f1)
        #find radius
        f1_radius=np.sqrt((f1.area)/np.pi)
        #buffer the polygon from the centroid
        f1_buffered=shapely.geometry.Point(f1.centroid).buffer(f1_radius*500)
        cont=[]
        # merge up the ground truth instance against prediction
        # to determine the IoU
        for i in range(len(preds)):
            ff=shapely.geometry.Polygon(np.squeeze(preds[i]))
            if f1_buffered.contains(ff)== True:
            #calculate IoU
                iou=(ff.intersection(f1).area)/(ff.union(f1).area)
                cont.append((iou))
      # probability of a given prediction to be contained in a
      # ground truth instance
        prob2.append(cont)
    fn=0
    tp=0
    for t in prob2:
        if np.sum(t)==0:
            fn=fn+1
        elif CheckLess(t,iou_value)==False:
            tp=tp+1
    print("TP:",tp,"\t FP:",fp,"\t FN:",fn,"\t GT:",truth.shape[0])
    precision=round(tp/(tp+fp),3) 
    recall=round(tp/(tp+fn),3)
    f1= round(2*((precision*recall)/(precision+recall)),3)
    print("Precall:",precision,"\t Recall:",recall, "\t F1 score:",f1)
    return tp,fp,fn,precision,recall,f1

# %%
gt_path='data/membrane_hospital_aughand/test/labelpng'
evaluation(gt_path,results,0.5)

# %%
import umetrics
from skimage.io import imread
y_true = imread('./data/membrane_hospital_aughand/test/labelpng/0.png')
y_pred = imread('./data/membrane_hospital_aughand/test/pred_resize/0_predictmask_resize.png')


# can now make the calculation strict, by only considering objects that have
# an IoU above a theshold as being true positives
result = umetrics.calculate(y_true, y_pred, strict=True, iou_threshold=0.1)

print(result.results)

# %% [markdown]
# # prcurve寫錯

# %%
def PR_Result(gth_path,npyfile,target_size=(512,512),flag_multi_class = False,num_class = 2):
    files=sorted(os.listdir(gth_path))
    print(files)
    AP=np.zeros(100)
    for j in range(1, 99, 1):
        AP[j]=0
        for i,item in enumerate(npyfile):
            img = item[:,:,0]
            gth = io.imread(os.path.join(gth_path,files[i]))
            gth = trans.resize(gth,target_size)
            img1=np.array((img)>(j/1000)).astype(float)
            gth1=np.array(gth>0.1).astype(float)
            
            u,v=np.shape(gth1)
            groundtruth_list=np.reshape(gth1,(u*v,))
            predicted_list=np.reshape(img1,(u*v,))
            tn, fp, fn, tp = get_confusion_matrix_elements(groundtruth_list, predicted_list)
            AP[j] = (tp/(tp+fp))+ AP[j]
        AP[j] = AP[j]/(i+1)
        print("AP[",j,"]=",AP[j])
            
    return AP

# %%
import matplotlib
matplotlib.use("Agg")
import numpy as np
import matplotlib.pyplot as plt
plt.figure(1) # 建立圖表1
plt.title('Precision/Recall Curve')# give plot a title
plt.xlabel('Recall')# make axis labels
plt.ylabel('Precision')

#x、y都是列表，裡面存的分別是recall和precision
#傳參得到或讀取檔案得到無所謂
z=[]
r=[]

for i in range(0, 100, 1):
    r.append(prec[i])
    z.append(1-rec[i])

plt.figure(1)
plt.plot(z, r)
plt.show()
plt.savefig('p-r.png')
# Out:
# C:\Users\414\AppData\Local\Temp/ipykernel_13464/3280530832.py:21: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
prec=np.zeros(100)
rec=np.zeros(100)
for j in range(0, 100, 1):
    print (j/100.)
    prec[j],rec[j] = evalResult(gt_path,results,target_size=(512,512),threshold=(j/100.))
# Out:
# 0.0
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.47629571197270193 Recall= 0.9980123788830153 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.01
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.0631660036933834 Recall= 0.06863363812618888 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.02
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.0631660036933834 Recall= 0.06863363812618888 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.03
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.0631660036933834 Recall= 0.06863363812618888 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.04
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.05
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.06
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.07
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.08
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.09
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.1
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.11
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.12
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.13
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.14
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.15
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.16
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.17
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.18
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.19
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.2
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.21
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.22
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.23
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.24
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.25
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.26
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.27
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.28
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.29
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.3
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.31
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.32
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.33
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.34
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.35
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.36
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.37
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.38
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.39
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.4
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.41
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.42
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.43
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.44
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.45
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.46
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.036234094061521484 Recall= 0.035305497305252675 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.47
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.48
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.49
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.5
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.51
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.52
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.53
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.54
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.55
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.56
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.57
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.58
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.59
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.6
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.61
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.62
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.63
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.64
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.65
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.66
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.67
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.68
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.69
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.7
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.71
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.72
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.73
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.74
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.75
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.76
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.77
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.78
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.79
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.8
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.81
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.82
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.83
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.84
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.85
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.86
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.87
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.88
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.89
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.9
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.91
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.92
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.93
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.94
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.95
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.96
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.97
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.98
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843
# 0.99
# ['0.png', '1.png', '10.png', '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# Precision= 0.005000754974779264 Recall= 0.0019876211169846613 IoU= 0.01661818825906149 acc= 0.9762947082519531 F1= 0.023375676570981843

# %%
gt_path='data/membrane_hospital_aughand/test/labelpng'
# evalResult(gt_path,results)
AP = PR_Result(gt_path,results)

import matplotlib
matplotlib.use("Agg")
import numpy as np
import matplotlib.pyplot as plt
plt.figure(1) # 建立圖表1
plt.title('Precision/Recall Curve')# give plot a title
plt.xlabel('Recall')# make axis labels
plt.ylabel('Precision')

#x、y都是列表，裡面存的分別是recall和precision
#傳參得到或讀取檔案得到無所謂
x=[]
y=[]
#f=open('eval.txt','r')
#lines=f.readlines()
for i in range(1, 99, 1):
    y.append(AP[i])
    x.append(i)

plt.figure(1)
plt.plot(x, y)
plt.show()
plt.savefig('p-r.png')
